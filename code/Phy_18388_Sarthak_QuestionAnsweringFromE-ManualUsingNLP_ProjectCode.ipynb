# %% [markdown]
# ### Sarthak Mishra
# ### Roll No- 18388
# ### Department of Physics, IISER Bhopal

# %% [markdown]
# # Question Answering from e-manual using word embeddings in NLP

# %%
import pandas as pd

# data collected from kaggle competition: e-manual Datathon 2021
df = pd.read_json("../data/emanual_dataset.json")
df
# Out:
#                                               Question    Type  \
# 0                                  what is sound mode?  Normal
# 1                could you explain about sound output?  Normal
# 2                 what is the function of sleep timer?  Normal
# 3            where can i can view the current network?  Normal
# 4    how to select an external device connected to ...  Normal
# ..                                                 ...     ...
# 541  can i cancel scheduled viewing / cancel schedu...  Yes_No
# 542  is my samsung smart remote automatically pairs...  Yes_No
# 543  is it possible to install different apps using...  Yes_No
# 544  can i change the content and settings for ambi...  Yes_No
# 545  can i connect various external devices to my tv ?  Yes_No
#
#                                                 Answer   id
# 0    when the focus is moved to the icon, a list of...    0
# 1    when the focus is moved to the icon, a list of...    1
# 2    when the focus is moved to the icon, a list of...    2
# 3    when the focus is moved to the icon, a list of...    3
# 4    you can select an external device connected to...    4
# ..                                                 ...  ...
# 541                                                yes  541
# 542                                                yes  542
# 543                                                yes  543
# 544                                                yes  544
# 545                                                yes  545
#
# [546 rows x 4 columns]

# %%
df['Type'].unique()
# Out:
# array(['Normal', 'Paraphrased', 'Compound', 'Yes_No'], dtype=object)

# %%
# only the required columns 
df = df[['Question', 'Answer']].reset_index(drop=True)
# renaming better accessibility
df.columns = ['questions', 'answers']
df
# Out:
#                                              questions  \
# 0                                  what is sound mode?
# 1                could you explain about sound output?
# 2                 what is the function of sleep timer?
# 3            where can i can view the current network?
# 4    how to select an external device connected to ...
# ..                                                 ...
# 541  can i cancel scheduled viewing / cancel schedu...
# 542  is my samsung smart remote automatically pairs...
# 543  is it possible to install different apps using...
# 544  can i change the content and settings for ambi...
# 545  can i connect various external devices to my tv ?
#
#                                                answers
# 0    when the focus is moved to the icon, a list of...
# 1    when the focus is moved to the icon, a list of...
# 2    when the focus is moved to the icon, a list of...
# 3    when the focus is moved to the icon, a list of...
# 4    you can select an external device connected to...
# ..                                                 ...
# 541                                                yes
# 542                                                yes
# 543                                                yes
# 544                                                yes
# 545                                                yes
#
# [546 rows x 2 columns]

# %% [markdown]
# # Preprocessing
#
# For this task I have performed the following preprocessing :
# 1. Removing all characters that are not alpha numeric
# 2. Removing stopwords - commonly used words such as 'a', 'to', 'in' and so on, since they do not contribute to the semantic similarity between two sentences.
#
# I have applied this to both the e-Manual questions and the user query sentence.
#
# I have also printed a list of sentences without removing stopwords.

# %%
import re
import gensim 
from gensim.parsing.preprocessing import remove_stopwords

def clean_sentence(sentence, stopwords=False):
    
    sentence = sentence.lower().strip()
    sentence = re.sub(r'[^a-z0-9\s]', '', sentence)
    
    if stopwords:
         sentence = remove_stopwords(sentence)
    return sentence
                    
def get_cleaned_sentences(df,stopwords=False):    
    sents=df[["questions"]]
    cleaned_sentences=[]

    for index,row in df.iterrows():
        cleaned=clean_sentence(row["questions"],stopwords)
        cleaned_sentences.append(cleaned)
    return cleaned_sentences

cleaned_sentences=get_cleaned_sentences(df,stopwords=True)
print("Cleaned sentences without stop words:-\n", cleaned_sentences)

print("\n\n\n")

cleaned_sentences_with_stopwords=get_cleaned_sentences(df,stopwords=False)
print("Cleaned sentences with stop words:-\n", cleaned_sentences_with_stopwords)
# Out:
# Cleaned sentences without stop words:-
#  ['sound mode', 'explain sound output', 'function sleep timer', 'view current network', 'select external device connected tv', 'search apps smart hub services', 'use feature apps', 'turn tv ambient mode', 'item home screen', 'turn autorun smart hub function', 'launch app automatically', 'test smart hub connections', 'reset smart hub', 'create manage samsung account', 'create new account', 'create samsung account facebook account', 'create samsung account paypal account', 'change information samsung account', 'configure sync internet settings', 'delete samsung account', 'sign samsung account', 'view privacy policy', 'install app', 'delete app', 'add apps home screen', 'need lock app', 'app location', 'reinstall apps', 'update apps automatically', 'rate apps', 'use universal guide', 'smartthings', 'select location list smart', 'create new account smartthings', 'items turn notifications', 'create custom mode', 'view list connected smart devices', 'launch emanual', 'uses buttons emanual', 'surf internet tv', 'tv getting hot', 'getting display picture', 'mode supported appears screen fix', 'captions tv grayed fix', 'tv smells plastic', 'stand wobbly crooked', 'broadcasting function deactivated', 'pip available', 'settings lost everytime tv turned', 'pop tvs internal banner ad appears screen change', 'software update internet failed fix', 'rotate samsung tv screen', 'happen press color buttons', 'things playpause button', 'use voice guide', 'enlarge screen', 'option learn tv remote', 'option learn menu screen', 'open accessibility shortcuts menu', 'turn voice guide', 'turn video description', 'access main accessibility menu change voice guide settings', 'turn voice guide bixby', 'turn video description bixby', 'turn high contrast bixby', 'turn tv voice', 'change channel', 'view program information', 'schedule program', 'edit recording time', 'stop recording', 'cancel scheduled viewing cancel scheduled recording', 'details program', 'list favorite channels', 'guide screen option', 'program info screen', 'cancel scheduled view guide', 'check list channels', 'check list favorite channels', 'register channels favorite', 'add channels favorite list', 'delete channels favorite list', 'view select channels favorite lists', 'start recording', 'timeshift', 'stop recording', 'information program', 'set length recording time', 'recorded program', 'steps delete recorded program', 'open channel list', 'schedule manager recordings', 'view program watched recently', 'delete notification', 'select services want notified', 'change picture mode', 'change sound mode', 'change sound output', 'check current network internet status', 'change source', 'different types things ambient mode', 'emanual', 'activate bixby', 'delete recorded content', 'precautions bixby', 'instruct record program', 'provide instructions schedule program', 'explain schedule recording', 'explain procedure edit recording time', 'way stop recording', 'program information', 'select channel filter option', 'change antenna type', 'check schedule manager option', 'instant recording guide screen', 'explain steps schedule recording guide screen', 'explain steps schedule recording watching program', 'explain steps schedule recording watching program', 'schedule recording date time entered', 'manage recording list', 'delete schedule recordings', 'recording list', 'start early recording', 'continue recording program ended', 'edit scheduled viewing', 'set scheduled viewing time', 'cancel sheduled viewing', 'check scheduled viewings', 'record time timeshift function', 'live tv', 'stop recording stop timeshift', 'slow forward slow rewind', 'jump forward jump backward', 'fast forward rewind', 'lock current channel', 'view channels serached auto program function', 'select air cable dtv mode', 'use tv plus', 'add removed channels', 'rename channel', 'watch blocked restricted channels', 'steps register channels favorites', 'select view channels favorite list', 'edit favorites list', 'add channels f ...
#
#
#
#
# Cleaned sentences with stop words:-
#  ['what is sound mode', 'could you explain about sound output', 'what is the function of sleep timer', 'where can i can view the current network', 'how to select an external device connected to the tv', 'where can i search the apps in smart hub services', 'how to use the feature of apps', 'how to turn tv in ambient mode', 'how to move item on the home screen', 'how to turn on the autorun smart hub function', 'how to launch the last used app automatically', 'how to test the smart hub connections', 'how to reset smart hub', 'how to create and manage my samsung account', 'how to create new account', 'how to create a samsung account using a facebook account', 'can i create a samsung account using a paypal account', 'how to change the information to a samsung account', 'how to configure the sync internet settings', 'how to delete samsung account', 'how to sign out of samsung account', 'where to view privacy policy', 'how to install app', 'how to delete an app', 'how to add apps to the home screen', 'i need to lock app how to do this', 'how to move app from one location to other', 'how to reinstall apps', 'how to update apps automatically', 'how to rate apps', 'what is the use of universal guide', 'what is smartthings', 'how to select location list in smart', 'how to create new account in smartthings ', 'for which items can i turn off notifications', 'can i create custom mode', 'where can i view list of the connected smart devices', 'how to launch the emanual', 'what are the uses of buttons in the emanual', 'how to surf internet on my tv', 'what can i do if my tv is getting hot', 'i am not getting full display picture how do i do that', 'mode not supported appears on screen how to fix this', 'the captions in the tv is grayed out how should i fix it', 'why the tv smells of plastic', 'why the stand is wobbly or crooked', 'why the broadcasting function has been deactivated', 'why there is no pip available', 'why my settings are lost everytime the tv is turned off', 'why this pop tvs internal banner ad appears on the screen how do i change this ', 'my software update over the internet has failed how do i fix this', 'how do i rotate my samsung tv screen', 'what will happen if i press the color buttons', 'what are the things we can do with playpause button', 'how do i use voice guide ', 'how do i enlarge screen', 'where do i find the option of learn tv remote', 'where do i find the option of learn menu screen', 'how do i open the accessibility shortcuts menu', 'how do i turn on the voice guide', 'how do i turn on video description', 'how do i access the main accessibility menu to change voice guide settings', 'how do i turn on voice guide using bixby', 'how do i turn on video description using bixby', 'how do i turn on high contrast using bixby', 'how do i turn on the tv using voice', 'how do i change channel', 'how can i view program information', 'how can i schedule any program', 'how can i edit recording time', 'how can i stop the recording', 'how do i cancel scheduled viewing  cancel scheduled recording', 'where do i find the details of program', 'where do i find the list of my favorite channels', 'where do i find guide screen option', 'where do i find program info screen', 'how do i cancel scheduled view from the guide', 'where do i check the list of my all channels', 'how can i check the list of my favorite channels', 'how to register channels as favorite', 'how to add channels to favorite list', 'how to delete channels from favorite list', 'how can i view and select channels on my favorite lists only', 'how do i start recording', 'what is timeshift', 'how do i stop recording', 'where do i find information about my program', 'how do i set length of recording time', 'where can i find my recorded program', 'what are the steps to delete the recorded program', 'how do i open channel list', 'where do i find schedule manager or recordings', 'how can i view which program i watched recently', 'how do i delete notification', 'how do i select ...
# /home/nusart/anaconda3/lib/python3.8/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # Bag of words Model

# %%
import numpy

sentences=cleaned_sentences_with_stopwords

# Split it by white space 
sentence_words = [[word for word in document.split() ]
         for document in sentences]

from gensim import corpora

dictionary = corpora.Dictionary(sentence_words)
for key, value in dictionary.items():
    print(key, ' : ', value)

import pprint
bow_corpus = [dictionary.doc2bow(text) for text in sentence_words]
for sent,embedding in zip(sentences,bow_corpus):
    print(sent)
    print(embedding)

question_orig="signal information under self diagnosis isn't activated. how do i activate that?"
question=clean_sentence(question_orig,stopwords=False)
question_embedding = dictionary.doc2bow(question.split())


print("\n\n",question,"\n",question_embedding)
# Out:
# 0  :  is
# 1  :  mode
# 2  :  sound
# 3  :  what
# 4  :  about
# 5  :  could
# 6  :  explain
# 7  :  output
# 8  :  you
# 9  :  function
# 10  :  of
# 11  :  sleep
# 12  :  the
# 13  :  timer
# 14  :  can
# 15  :  current
# 16  :  i
# 17  :  network
# 18  :  view
# 19  :  where
# 20  :  an
# 21  :  connected
# 22  :  device
# 23  :  external
# 24  :  how
# 25  :  select
# 26  :  to
# 27  :  tv
# 28  :  apps
# 29  :  hub
# 30  :  in
# 31  :  search
# 32  :  services
# 33  :  smart
# 34  :  feature
# 35  :  use
# 36  :  ambient
# 37  :  turn
# 38  :  home
# 39  :  item
# 40  :  move
# 41  :  on
# 42  :  screen
# 43  :  autorun
# 44  :  app
# 45  :  automatically
# 46  :  last
# 47  :  launch
# 48  :  used
# 49  :  connections
# 50  :  test
# 51  :  reset
# 52  :  account
# 53  :  and
# 54  :  create
# 55  :  manage
# 56  :  my
# 57  :  samsung
# 58  :  new
# 59  :  a
# 60  :  facebook
# 61  :  using
# 62  :  paypal
# 63  :  change
# 64  :  information
# 65  :  configure
# 66  :  internet
# 67  :  settings
# 68  :  sync
# 69  :  delete
# 70  :  out
# 71  :  sign
# 72  :  policy
# 73  :  privacy
# 74  :  install
# 75  :  add
# 76  :  do
# 77  :  lock
# 78  :  need
# 79  :  this
# 80  :  from
# 81  :  location
# 82  :  one
# 83  :  other
# 84  :  reinstall
# 85  :  update
# 86  :  rate
# 87  :  guide
# 88  :  universal
# 89  :  smartthings
# 90  :  list
# 91  :  for
# 92  :  items
# 93  :  notifications
# 94  :  off
# 95  :  which
# 96  :  custom
# 97  :  devices
# 98  :  emanual
# 99  :  are
# 100  :  buttons
# 101  :  uses
# 102  :  surf
# 103  :  getting
# 104  :  hot
# 105  :  if
# 106  :  am
# 107  :  display
# 108  :  full
# 109  :  not
# 110  :  picture
# 111  :  that
# 112  :  appears
# 113  :  fix
# 114  :  supported
# 115  :  captions
# 116  :  grayed
# 117  :  it
# 118  :  should
# 119  :  plastic
# 120  :  smells
# 121  :  why
# 122  :  crooked
# 123  :  or
# 124  :  stand
# 125  :  wobbly
# 126  :  been
# 127  :  broadcasting
# 128  :  deactivated
# 129  :  has
# 130  :  available
# 131  :  no
# 132  :  pip
# 133  :  there
# 134  :  everytime
# 135  :  lost
# 136  :  turned
# 137  :  ad
# 138  :  banner
# 139  :  internal
# 140  :  pop
# 141  :  tvs
# 142  :  failed
# 143  :  over
# 144  :  software
# 145  :  rotate
# 146  :  color
# 147  :  happen
# 148  :  press
# 149  :  will
# 150  :  button
# 151  :  playpause
# 152  :  things
# 153  :  we
# 154  :  with
# 155  :  voice
# 156  :  enlarge
# 157  :  find
# 158  :  learn
# 159  :  option
# 160  :  remote
# 161  :  menu
# 162  :  accessibility
# 163  :  open
# 164  :  shortcuts
# 165  :  description
# 166  :  video
# 167  :  access
# 168  :  main
# 169  :  bixby
# 170  :  contrast
# 171  :  high
# 172  :  channel
# 173  :  program
# 174  :  any
# 175  :  schedule
# 176  :  edit
# 177  :  recording
# 178  :  time
# 179  :  stop
# 180  :  cancel
# 181  :  scheduled
# 182  :  viewing
# 183  :  details
# 184  :  channels
# 185  :  favorite
# 186  :  info
# 187  :  all
# 188  :  check
# 189  :  as
# 190  :  register
# 191  :  lists
# 192  :  only
# 193  :  start
# 194  :  timeshift
# 195  :  length
# 196  :  set
# 197  :  recorded
# 198  :  steps
# 199  :  manager
# 200  :  recordings
# 201  :  recently
# 202  :  watched
# 203  :  notification
# 204  :  get
# 205  :  notified
# 206  :  want
# 207  :  status
# 208  :  source
# 209  :  different
# 210  :  types
# 211  :  activate
# 212  :  content
# 213  :  precautions
# 214  :  instruct
# 215  :  please
# 216  :  record
# 217  :  instructions
# 218  :  provide
# 219  :  some
# 220  :  procedure
# 221  :  way
# 222  :  see
# 223  :  filter
# 224  :  antenna
# 225  :  type
# 226  :  instant
# 227  :  watching
# 228  :  while
# 229  :  already
# 230  :  date
# 231  :  entered
# 232  :  when
# 233  :  early
# 234  :  after
# 235  :  continue
# 236  :  ended
# 237  :  even
# 238  :  sheduled
# 239  :  viewings
# 240  :  go
# 241  :  live
# 242  :  forward
# 243  :  rewind
# 244  :  slow
# 245  :  backward
# 246  :  jump
# 247  :  fast
# 248  :  auto
# 249  :  by
# 250  :  serached
# 251  :  air
# 252  :  cable
# 253  :  dtv
# 254  :  plus
# 255  :  again
# 256  :  removed
# 257  :  name
# 258  :  rename
# 259  :  blocked
# 260  :  restricted
# 261  :  watch
# 262  :  favorites
# 263  :  remove
# 264  :  rearrange
# 265  :  signal
# 266  :  scan
# 267  :  advanced
# 268  :  audio
# 269  :  hpw
# 270  :  multitrack
# 271  :  connect
# 272  :  samsungsmartremote
# 273  :  icon
# 274  :  tne
# 275  :  became
# 276  :  black
# 277  :  enter
# 278  :  beautiful
# 279  :  screens
# 280  :  weather
# 281  :  wallpaper
# 282  :  adjust
# 283  :  brightness
# 284  :  setting
# 285  :  background
# 286  :  dynamic
# 287  :  standard
# 288  :  natural
# 289  :  movie
# 290  :  backlight
# 291  :  sharpness
# 292  :  tint
# 293  :  apply
# 294  :  clean
# 295  :  digital
# 296  :  motion
# 297  :  dimming
# 298  :  local
# 299  :  enhancer
# 300  :  hdr
# 301  :  film
# 302  :  tone
# 303  :  gamma
# 304  :  rgb
# 305  :  space
# 306  :  game
# 307  :  hdmi
# 308  :  uhd
# 309  :  level
# 310  :  169
# 311  :  size
# 312  :  43
# 313  :  fit
# 314  :  optimized
# 315  :  amplify
# 316  :  balance
# 317  :  quality
# 318  :  volume
# 319  :  feedback
# 320  :  speaker
# 321  :  bluetooth
# 322  :  cases
# 323  :  clock
# 324  :  zone
# 325  :  daylight
# 326  :  dst
# 327  :  saving
# 328  :  manually
# 329  :  detection
# 330  :  light
# 331  :  minimum
# 332  :  through
# 333  :  usb
# 334  :  security
# 335  :  code
# 336  :  malicious
# 337  :  experience
# 338  :  points
# 339  :  xp
# 340  :  be
# 341  :  must
# 342  :  required
# 343  :  requirements
# 344  :  version
# 345  :  management
# 346  :  support
# 347  :  call
# 348  :  center
# 349  :  number
# 350  :  phone
# 351  :  having
# 352  :  problem
# 353  :  request
# 354  :  service
# 355  :  connection
# 356  :  establishing
# 357  :  wired
# 358  :  mobile
# 359  :  ipv6
# 360  :  up
# 361  :  changing
# 362  :  ip
# 363  :  resolve
# 364  :  unable
# 365  :  dns
# 366  :  values
# 367  :  component
# 368  :  connecting
# 369  :  speakers
# 370  :  via
# 371  :  input
# 372  :  notes
# 373  :  computers
# 374  :  pair
# 375  :  functions
# 376  :  enable
# 377  :  grayscale
# 378  :  colors
# 379  :  invert
# 380  :  caption
# 381  :  language
# 382  :  effect
# 383  :  enabledisable
# 384  :  retail
# 385  :  usage
# 386  :  factory
# 387  :  does
# 388  :  offer
# 389  :  flickering
# 390  :  issues
# 391  :  blurring
# 392  :  issue
# 393  :  powering
# 394  :  unwanted
# 395  :  found
# 396  :  distorted
# 397  :  missingwrong
# 398  :  poor
# 399  :  dotted
# 400  :  edge
# 401  :  line
# 402  :  white
# 403  :  low
# 404  :  but
# 405  :  good
# 406  :  hear
# 407  :  odd
# 408  :  weak
# 409  :  computer
# 410  :  message
# 411  :  able
# 412  :  wireless
# 413  :  too
# 414  :  working
# 415  :  anynet
# 416  :  exit
# 417  :  connectingdisconnecting
# 418  :  play
# 419  :  wont
# 420  :  displaying
# 421  :  being
# 422  :  played
# 423  :  receiver
# 424  :  know
# 425  :  dont
# 426  :  briefly
# 427  :  becomes
# 428  :  darker
# 429  :  explian
# 430  :  like
# 431  :  position
# 432  :  equalizer
# 433  :  format
# 434  :  delay
# 435  :  enabled
# 436  :  wifi
# 437  :  burn
# 438  :  prevent
# 439  :  power
# 440  :  otion
# 441  :  activated
# 442  :  acoount
# 443  :  names
# 444  :  saying
# 445  :  mean
# 446  :  facing
# 447  :  problems
# 448  :  establish
# 449  :  control
# 450  :  error
# 451  :  router
# 452  :  composite
# 453  :  bidirectional
# 454  :  mirroring
# 455  :  registered
# 456  :  recommended
# 457  :  better
# 458  :  guidelines
# 459  :  font
# 460  :  increase
# 461  :  features
# 462  :  listen
# 463  :  troubleshoot
# 464  :  receiving
# 465  :  data
# 466  :  serch
# 467  :  also
# 468  :  sometimes
# 469  :  state
# 470  :  decor
# 471  :  style
# 472  :  user
# 473  :  works
# 474  :  back
# 475  :  adjusts
# 476  :  lighting
# 477  :  cc1
# 478  :  cc4
# 479  :  default
# 480  :  service1
# 481  :  service6
# 482  :  text1
# 483  :  text4
# 484  :  cancelling
# 485  :  possible
# 486  :  pairs
# 487  :  various
# what is sound mode
# [(0, 1), (1, 1), (2, 1), (3, 1)]
# could you explain about sound output
# [(2, 1), (4, 1), (5, 1), (6, 1), (7, 1), (8, 1)]
# what is the function of sleep timer
# [(0, 1), (3, 1), (9, 1), (10, 1), (11, 1), (12, 1), (13, 1)]
# where can i can view the current network
# [(12, 1), (14, 2), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1)]
# how to select an external device connected to the tv
# [(12, 1), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 2), (27, 1)]
# where can i search the apps in smart hub services
# [(12, 1), (14, 1), (16, 1), (19, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 1), (33, 1)]
# how to use the feature of apps
# [(10, 1), (12, 1), (24, 1), (26, 1), (28, 1), (34, 1), (35, 1)]
# how to turn tv in ambient mode
# [(1, 1), (24, 1), (26, 1), (27, 1), (30, 1), (36, 1), (37, 1)]
# how to move item on the home screen
# [(12, 1), (24, 1), (26, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 1)]
# how to turn on the autorun smart hub function
# [(9, 1), (12, 1), (24, 1), (26, 1), (29, 1), (33, 1), (37, 1), (41, 1), (43, 1)]
# how to launch the last used app automatically
# [(12, 1), (24, 1), (26, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1)]
# how to test the smart hub connections
# [(12, 1), (24, 1), (26, 1), (29, 1), (33, 1), (49, 1), (50, 1)]
# how to reset smart hub
# [(24, 1), (26, 1), (29, 1), (33, 1), (51, 1)]
# how to create and manage my samsung account
# [(24, 1), (26, 1), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1)]
# how to create new account
# [(24, 1), (26, 1), (52, 1), (54, 1), (58, 1)]
# how to create a samsung account using a facebook account
# [(24, 1), (26, 1), (52, 2), (54, 1), (57, 1), (59, 2), (60, 1), (61, 1)]
# can i create a samsung account using a paypal account
# [(14, 1), (16, 1), (52, 2), (54, 1), (57, 1), (59, 2), (61, 1), (62, 1)]
# how to change the information to a samsung account
# [(12, 1), (24, 1), (26, 2), (52, 1), (57, 1), (59, 1), (63, 1), (64, 1)]
# how to configure the sync internet settings
# [(12, 1), (24, 1), (26, 1), (65, 1), (66, 1), (67, 1), (68, 1)]
# how to delete samsung account
# [(24, 1), (26, 1), (52, 1), (57, 1), (69, 1)]
# how to sign out of samsung account
# [(10, 1), (24, 1), (26, 1), (52, 1), (57, 1), (70, 1), (71, 1)]
# where to view privacy policy
# [(18, 1), (19, 1), (26, 1), (72, 1), (73, 1)]
# how to install app
# [(24, 1), (26, 1), (44, 1), (74, 1)]
# how to delete an app
# [(20, 1), (24, 1), (26, 1), (44, 1), (69, 1)]
# how to add apps to the home screen
# [(12, 1), (24, 1), (26, 2), (28, 1), (38, 1), (42, 1), (75, 1)]
# i need to lock app how to do this
# [(16, 1), (24, 1), (26, 2), (44, 1), (76, 1), (77, 1), (78, 1), (79, 1)]
# how to move app from one location to other
# [(24, 1), (26, 2), (40, 1), (44, 1), (80, 1), (81, 1), (82, 1), (83, 1)]
# how to reinstall apps
# [(24, 1), (26, 1), (28, 1), (84, 1)]
# how to update apps automatically
# [(24, 1), (26, 1), (28, 1), (45, 1), (85, 1)]
# how to rate apps
# [(24, 1), (26, 1), (28, 1), (86, 1)]
# what is the use of universal guide
# [(0, 1), (3, 1), (10, 1), (12, 1), (35, 1), (87, 1), (88, 1)]
# what is smartthings
# [(0, 1), (3, 1), (89, 1)]
# how to select location list in smart
# [(24, 1), (25, 1), (26, 1), (30, 1), (33, 1), (81, 1), (90, 1)]
# how to create new account in smartthings
# [(24, 1), (26, 1), (30, 1), (52, 1), (54, 1), (58, 1), (89, 1)]
# for which items can i turn off notifications
# [(14, 1), (16, 1), (37, 1), (91, 1), (92, 1), (93, 1), (94, 1), (95, 1)]
# can i create custom mode
# [(1, 1), (14, 1), (16, 1), (54, 1), (96, 1)]
# where can i view list of the connected smart devices
# [(10, 1), (12, 1), (14, 1), (16, 1), (18, 1), (19, 1), (21, 1), (33, 1), (90, 1), (97, 1)]
# how to launch the emanual
# [(12, 1), (24, 1), (26, 1), (47, 1), (98, 1)]
# what are the uses of buttons in the emanual
# [(3, 1), (10, 1), (12, 2), (30, 1), (98, 1), (99, 1), (100, 1), (101, 1)]
# how to surf internet on my tv
# [(24, 1), (26, 1), (27, 1), (41, 1), (56, 1), (66, 1), (102, 1)]
# what can i do if my tv is getting hot
# [(0, 1), (3, 1), (14, 1), (16, 1), (27, 1), (56, 1), (76, 1), (103, 1), (104, 1), (105, 1)]
# i am not getting full display picture how do i do that
# [(16, 2), (24, 1), (76, 2), (103, 1), (106, 1), (107, 1), (108, 1), (109, 1), (110, 1), (111, 1)]
# mode not supported appears on screen how to fix this
# [(1, 1), (24, 1), (26, 1), (41, 1), (42, 1), (79, 1), (109, 1), (112, 1), (113, 1), (114, 1)]
# the captions in the tv is grayed out how should i fix it
# [(0, 1), (12, 2), (16, 1), (24, 1), (27, 1), (30, 1), (70, 1), (113, 1), (115, 1), (116, 1), (117, 1), (118, 1)]
# why the tv smells of plastic
# [(10, 1), (12, 1), (27, 1), (119, 1), (120, 1), (121, 1)]
# why the stand is wobbly or crooked
# [(0, 1), (12, 1), (121, 1), (122, 1), (123, 1), (124, 1), (125, 1)]
# why the broadcasting function has been deactivated
# [(9, 1), (12, 1), (121, 1), (126, 1), (127, 1), (128, 1), (129, 1)]
# why there is no pip available
# [(0, 1), (121, 1), (130, 1), (131, 1), (132, 1), (133, 1)]
# why my settings are lost everytime the tv is turned off
# [(0, 1), (12, 1), (27, 1), (56, 1), (67, 1), (94, 1), (99, 1), (121, 1), (134, 1), (135, 1), (136, 1)]
# why this pop tvs internal banner ad appears on the screen how do i change this
# [(12, 1), (16, 1), (24, 1), (41, 1), (42, 1), (63, 1), (76, 1), (79, 2), (112, 1), (121, 1), (137, 1), (138, 1), (139, 1), (140, 1), (141, 1)]
# my software update over the internet has failed how do i fix this
# [(12, 1), (16, 1), (24, 1), (56, 1), (66, 1), (76, 1), (79, 1), (85, 1), (113, 1), (129, 1), (142, 1), (143, 1), (144, 1)]
# how do i rotate my samsung tv screen
# [(16, 1), (24, 1), (27, 1), (42, 1), (56, 1), (57, 1), (76, 1), (145, 1)]
# what will happen if i press the color buttons
# [(3, 1), (12, 1), (16, 1), (100, 1), (105, 1), (146, 1), (147, 1), (148, 1), (149, 1)]
# what are the things we can do with playpause button
# [(3, 1), (12, 1), (14, 1), (76, 1), (99, 1), (150, 1), (151, 1), (152, 1), (153, 1), (154, 1)]
# how do i use voice guide
# [(16, 1), (24, 1), (35, 1), (76, 1), (87, 1), (155, 1)]
# how do i enlarge screen
# [(16, 1), (24, 1), (42, 1), (76, 1), (156, 1)]
# where do i find the option of learn tv remote
# [(10, 1), (12, 1), (16, 1), (19, 1), (27, 1), (76, 1), (157, 1), (158, 1), (159, 1), (160, 1)]
# where do i find the option of learn menu screen
# [(10, 1), (12, 1), (16, 1), (19, 1), (42, 1), (76, 1), (157, 1), (158, 1), (159, 1), (161, 1)]
# how do i open the accessibility shortcuts menu
# [(12, 1), (16, 1), (24, 1), (76, 1), (161, 1), (162, 1), (163, 1), (164, 1)]
# how do i turn on the voice guide
# [(12, 1), (16, 1), (24, 1), (37, 1), (41, 1), (76, 1), (87, 1), (155, 1)]
# how do i turn on video description
# [(16, 1), (24, 1), (37, 1), (41, 1), (76, 1), (165, 1), (166, 1)]
# how do i access the main accessibility menu to change voice guide settings
# [(12, 1), (16, 1), (24, 1), (26, 1), (63, 1), (67, 1), (76, 1), (87, 1), (155, 1), (161, 1), (162, 1), (167, 1), (168, 1)]
# how do i turn on voice guide using bixby
# [(16, 1), (24, 1), (37, 1), (41, 1), (61, 1), (76, 1), (87, 1), (155, 1), (169, 1)]
# how do i turn on video description using bixby
# [(16, 1), (24, 1), (37, 1), (41, 1), (61, 1), (76, 1), (165, 1), (166, 1), (169, 1)]
# how do i turn on high contrast using bixby
# [(16, 1), (24, 1), (37, 1), (41, 1), (61, 1), (76, 1), (169, 1), (170, 1), (171, 1)]
# how do i turn on the tv using voice
# [(12, 1), (16, 1), (24, 1), (27, 1), (37, 1), (41, 1), (61, 1), (76, 1), (155, 1)]
# how do i change channel
# [(16, 1), (24, 1), (63, 1), (76, 1), (172, 1)]
# how can i view program information
# [(14, 1), (16, 1), (18, 1), (24, 1), (64, 1), (173, 1)]
# how can i schedule any program
# [(14, 1), (16, 1), (24, 1), (173, 1), (174, 1), (175, 1)]
# how can i edit recording time
# [(14, 1), (16, 1), (24, 1), (176, 1), (177, 1), (178, 1)]
# how can i stop the recording
# [(12, 1), (14, 1), (16, 1), (24, 1), (177, 1), (179, 1)]
# how do i cancel scheduled viewing  cancel scheduled recording
# [(16, 1), (24, 1), (76, 1), (177, 1), (180, 2), (181, 2), (182, 1)]
# where do i find the details of program
# [(10, 1), (12, 1), (16, 1), (19, 1), (76, 1), (157, 1), (173, 1), (183, 1)]
# where do i find the list of my favorite channels
# [(10, 1), (12, 1), (16, 1), (19, 1), (56, 1), (76, 1), (90, 1), (157, 1), (184, 1), (185, 1)]
# where do i find guide screen option
# [(16, 1), (19, 1), (42, 1), (76, 1), (87, 1), (157, 1), (159, 1)]
# where do i find program info screen
# [(16, 1), (19, 1), (42, 1), (76, 1), (157, 1), (173, 1), (186, 1)]
# how do i cancel scheduled view from the guide
# [(12, 1), (16, 1), (18, 1), (24, 1), (76, 1), (80, 1), (87, 1), (180, 1), (181, 1)]
# where do i check the list of my all channels
# [(10, 1), (12, 1), (16, 1), (19, 1), (56, 1), (76, 1), (90, 1), (184, 1), (187, 1), (188, 1)]
# how can i check the list of my favorite channels
# [(10, 1), (12, 1), (14, 1), (16, 1), (24, 1), (56, 1), (90, 1), (184, 1), (185, 1), (188, 1)]
# how to register channels as favorite
# [(24, 1), (26, 1), (184, 1), (185, 1), (189, 1), (190, 1)]
# how to add channels to favorite list
# [(24, 1), (26, 2), (75, 1), (90, 1), (184, 1), (185, 1)]
# how to delete channels from favorite list
# [(24, 1), (26, 1), (69, 1), (80, 1), (90, 1), (184, 1), (185, 1)]
# how can i view and select channels on my favorite lists only
# [(14, 1), (16, 1), (18, 1), (24, 1), (25, 1), (41, 1), (53, 1), (56, 1), (184, 1), (185, 1), (191, 1), (192, 1)]
# how do i start recording
# [(16, 1), (24, 1), (76, 1), (177, 1), (193, 1)]
# what is timeshift
# [(0, 1), (3, 1), (194, 1)]
# how do i stop recording
# [(16, 1), (24, 1), (76, 1), (177, 1), (179, 1)]
# where do i find information about my program
# [(4, 1), (16, 1), (19, 1), (56, 1), (64, 1), (76, 1), (157, 1), (173, 1)]
# how do i set length of recording time
# [(10, 1), (16, 1), (24, 1), (76, 1), (177, 1), (178, 1), (195, 1), (196, 1)]
# where can i find my recorded program
# [(14, 1), (16, 1), (19, 1), (56, 1), (157, 1), (173, 1), (197, 1)]
# what are the steps to delete the recorded program
# [(3, 1), (12, 2), (26, 1), (69, 1), (99, 1), (173, 1), (197, 1), (198, 1)]
# how do i open channel list
# [(16, 1), (24, 1), (76, 1), (90, 1), (163, 1), (172, 1)]
# where do i find schedule manager or recordings
# [(16, 1), (19, 1), (76, 1), (123, 1), (157, 1), (175, 1), (199, 1), (200, 1)]
# how can i view which program i watched recently
# [(14, 1), (16, 2), (18, 1), (24, 1), (95, 1), (173, 1), (201, 1), (202, 1)]
# how do i delete notification
# [(16, 1), (24, 1), (69, 1), (76, 1), (203, 1)]
# how do i select services that i want to get notified
# [(16, 2), (24, 1), (25, 1), (26, 1), (32, 1), (76, 1), (111, 1), (204, 1), (205, 1), (206, 1)]
# how to change the picture mode
# [(1, 1), (12, 1), (24, 1), (26, 1), (63, 1), (110, 1)]
# how to change the sound mode
# [(1, 1), (2, 1), (12, 1), (24, 1), (26, 1), (63, 1)]
# how to change the sound output
# [(2, 1), (7, 1), (12, 1), (24, 1), (26, 1), (63, 1)]
# how can i check the current network and internet status
# [(12, 1), (14, 1), (15, 1), (16, 1), (17, 1), (24, 1), (53, 1), (66, 1), (188, 1), (207, 1)]
# how can i change the source
# [(12, 1), (14, 1), (16, 1), (24, 1), (63, 1), (208, 1)]
# what are the different types of things we can do in ambient mode
# [(1, 1), (3, 1), (10, 1), (12, 1), (14, 1), (30, 1), (36, 1), (76, 1), (99, 1), (152, 1), (153, 1), (209, 1), (210, 1)]
# where do i find emanual
# [(16, 1), (19, 1), (76, 1), (98, 1), (157, 1)]
# how do i activate bixby
# [(16, 1), (24, 1), (76, 1), (169, 1), (211, 1)]
# how to delete the recorded content
# [(12, 1), (24, 1), (26, 1), (69, 1), (197, 1), (212, 1)]
# what are the precautions for bixby
# [(3, 1), (12, 1), (91, 1), (99, 1), (169, 1), (213, 1)]
# please instruct how to record any program
# [(24, 1), (26, 1), (173, 1), (174, 1), (214, 1), (215, 1), (216, 1)]
# please provide some instructions on how to schedule program
# [(24, 1), (26, 1), (41, 1), (173, 1), (175, 1), (215, 1), (217, 1), (218, 1), (219, 1)]
# can you please explain how to schedule recording
# [(6, 1), (8, 1), (14, 1), (24, 1), (26, 1), (175, 1), (177, 1), (215, 1)]
# please explain the procedure how to edit recording time
# [(6, 1), (12, 1), (24, 1), (26, 1), (176, 1), (177, 1), (178, 1), (215, 1), (220, 1)]
# is there any way to stop the recording
# [(0, 1), (12, 1), (26, 1), (133, 1), (174, 1), (177, 1), (179, 1), (221, 1)]
# from where i can see program information
# [(14, 1), (16, 1), (19, 1), (64, 1), (80, 1), (173, 1), (222, 1)]
# how can i select channel filter option
# [(14, 1), (16, 1), (24, 1), (25, 1), (159, 1), (172, 1), (223, 1)]
# how can i change antenna type
# [(14, 1), (16, 1), (24, 1), (63, 1), (224, 1), (225, 1)]
# from where i can check schedule manager option
# [(14, 1), (16, 1), (19, 1), (80, 1), (159, 1), (175, 1), (188, 1), (199, 1)]
# how do i do instant recording from the guide screen
# [(12, 1), (16, 1), (24, 1), (42, 1), (76, 2), (80, 1), (87, 1), (177, 1), (226, 1)]
# explain the steps how to do schedule recording from the guide screen
# [(6, 1), (12, 2), (24, 1), (26, 1), (42, 1), (76, 1), (80, 1), (87, 1), (175, 1), (177, 1), (198, 1)]
# explain the steps how to do schedule recording while watching a program
# [(6, 1), (12, 1), (24, 1), (26, 1), (59, 1), (76, 1), (173, 1), (175, 1), (177, 1), (198, 1), (227, 1), (228, 1)]
# explain the steps how to do schedule recording while watching a program
# [(6, 1), (12, 1), (24, 1), (26, 1), (59, 1), (76, 1), (173, 1), (175, 1), (177, 1), (198, 1), (227, 1), (228, 1)]
# how can i schedule recording when the date and time are already entered
# [(12, 1), (14, 1), (16, 1), (24, 1), (53, 1), (99, 1), (175, 1), (177, 1), (178, 1), (229, 1), (230, 1), (231, 1), (232, 1)]
# how can i manage recording list
# [(14, 1), (16, 1), (24, 1), (55, 1), (90, 1), (177, 1)]
# how can i delete schedule recordings
# [(14, 1), (16, 1), (24, 1), (69, 1), (175, 1), (200, 1)]
# where can i find the recording list
# [(12, 1), (14, 1), (16, 1), (19, 1), (90, 1), (157, 1), (177, 1)]
# how can i start early recording
# [(14, 1), (16, 1), (24, 1), (177, 1), (193, 1), (233, 1)]
# how can i continue recording even after program ended
# [(14, 1), (16, 1), (24, 1), (173, 1), (177, 1), (234, 1), (235, 1), (236, 1), (237, 1)]
# how do i edit scheduled viewing
# [(16, 1), (24, 1), (76, 1), (176, 1), (181, 1), (182, 1)]
# how do i set scheduled viewing time
# [(16, 1), (24, 1), (76, 1), (178, 1), (181, 1), (182, 1), (196, 1)]
# how to cancel sheduled viewing
# [(24, 1), (26, 1), (180, 1), (182, 1), (238, 1)]
# how do i check scheduled viewings
# [(16, 1), (24, 1), (76, 1), (181, 1), (188, 1), (239, 1)]
# how do i record using time timeshift function
# [(9, 1), (16, 1), (24, 1), (61, 1), (76, 1), (178, 1), (194, 1), (216, 1)]
# how to go to the live tv
# [(12, 1), (24, 1), (26, 2), (27, 1), (240, 1), (241, 1)]
# how do i stop recording  stop timeshift
# [(16, 1), (24, 1), (76, 1), (177, 1), (179, 2), (194, 1)]
# how to do slow forward or slow rewind
# [(24, 1), (26, 1), (76, 1), (123, 1), (242, 1), (243, 1), (244, 2)]
# how can i jump forward  jump backward
# [(14, 1), (16, 1), (24, 1), (242, 1), (245, 1), (246, 2)]
# how can i do fast forward  rewind
# [(14, 1), (16, 1), (24, 1), (76, 1), (242, 1), (243, 1), (247, 1)]
# how do i lock a current channel
# [(15, 1), (16, 1), (24, 1), (59, 1), (76, 1), (77, 1), (172, 1)]
# how can i view the channels that are serached by auto program function
# [(9, 1), (12, 1), (14, 1), (16, 1), (18, 1), (24, 1), (99, 1), (111, 1), (173, 1), (184, 1), (248, 1), (249, 1), (250, 1)]
# how to select air or cable as the dtv mode
# [(1, 1), (12, 1), (24, 1), (25, 1), (26, 1), (123, 1), (189, 1), (251, 1), (252, 1), (253, 1)]
# what is the use of tv plus
# [(0, 1), (3, 1), (10, 1), (12, 1), (27, 1), (35, 1), (254, 1)]
# how do i add removed channels again
# [(16, 1), (24, 1), (75, 1), (76, 1), (184, 1), (255, 1), (256, 1)]
# how to rename channel name
# [(24, 1), (26, 1), (172, 1), (257, 1), (258, 1)]
# how do i watch the blocked or restricted channels
# [(12, 1), (16, 1), (24, 1), (76, 1), (123, 1), (184, 1), (259, 1), (260, 1), (261, 1)]
# what are the steps to register channels as favorites
# [(3, 1), (12, 1), (26, 1), (99, 1), (184, 1), (189, 1), (190, 1), (198, 1), (262, 1)]
# how do i select and view channels from favorite list only
# [(16, 1), (18, 1), (24, 1), (25, 1), (53, 1), (76, 1), (80, 1), (90, 1), (184, 1), (185, 1), (192, 1)]
# how do i edit favorites list
# [(16, 1), (24, 1), (76, 1), (90, 1), (176, 1), (262, 1)]
# how to add channels to favorites list
# [(24, 1), (26, 2), (75, 1), (90, 1), (184, 1), (262, 1)]
# how to remove channels from favorites list
# [(24, 1), (26, 1), (80, 1), (90, 1), (184, 1), (262, 1), (263, 1)]
# how do i rearrange my favorites list
# [(16, 1), (24, 1), (56, 1), (76, 1), (90, 1), (262, 1), (264, 1)]
# how to change the broadcasting signal
# [(12, 1), (24, 1), (26, 1), (63, 1), (127, 1), (265, 1)]
# how to scan for available channels
# [(24, 1), (26, 1), (91, 1), (130, 1), (184, 1), (266, 1)]
# hpw do i configure advanced broadcasting audio settings
# [(16, 1), (65, 1), (67, 1), (76, 1), (127, 1), (267, 1), (268, 1), (269, 1)]
# where do i find multitrack sound option
# [(2, 1), (16, 1), (19, 1), (76, 1), (157, 1), (159, 1), (270, 1)]
# how can i connect samsungsmartremote to tv
# [(14, 1), (16, 1), (24, 1), (26, 1), (27, 1), (271, 1), (272, 1)]
# what is the use of notification icon on tv screen
# [(0, 1), (3, 1), (10, 1), (12, 1), (27, 1), (35, 1), (41, 1), (42, 1), (203, 1), (273, 1)]
# what is settings option in the smart hub
# [(0, 1), (3, 1), (12, 1), (29, 1), (30, 1), (33, 1), (67, 1), (159, 1)]
# what is source option in the smart hub
# [(0, 1), (3, 1), (12, 1), (29, 1), (30, 1), (33, 1), (159, 1), (208, 1)]
# what is the use of search option in tne smart hub
# [(0, 1), (3, 1), (10, 1), (12, 1), (29, 1), (30, 1), (31, 1), (33, 1), (35, 1), (159, 1), (274, 1)]
# what is the use of apps option in the smart hub
# [(0, 1), (3, 1), (10, 1), (12, 2), (28, 1), (29, 1), (30, 1), (33, 1), (35, 1), (159, 1)]
# how can i turn on ambient mode on tv screen
# [(1, 1), (14, 1), (16, 1), (24, 1), (27, 1), (36, 1), (37, 1), (41, 2), (42, 1)]
# what is universal guide
# [(0, 1), (3, 1), (87, 1), (88, 1)]
# can you explain ambient mode
# [(1, 1), (6, 1), (8, 1), (14, 1), (36, 1)]
# how my tv screen became black screen
# [(24, 1), (27, 1), (42, 2), (56, 1), (275, 1), (276, 1)]
# can i enter to ambient mode when the tv is turned off
# [(0, 1), (1, 1), (12, 1), (14, 1), (16, 1), (26, 1), (27, 1), (36, 1), (94, 1), (136, 1), (232, 1), (277, 1)]
# how to change the ambient mode settings
# [(1, 1), (12, 1), (24, 1), (26, 1), (36, 1), (63, 1), (67, 1)]
# from where i can select beautiful screens
# [(14, 1), (16, 1), (19, 1), (25, 1), (80, 1), (278, 1), (279, 1)]
# how to get information about weather
# [(4, 1), (24, 1), (26, 1), (64, 1), (204, 1), (280, 1)]
# how can i to set wallpaper of the ambient mode screen
# [(1, 1), (10, 1), (12, 1), (14, 1), (16, 1), (24, 1), (26, 1), (36, 1), (42, 1), (196, 1), (281, 1)]
# how to adjust the screen brightness
# [(12, 1), (24, 1), (26, 1), (42, 1), (282, 1), (283, 1)]
# how to change the auto brightness setting
# [(12, 1), (24, 1), (26, 1), (63, 1), (248, 1), (283, 1), (284, 1)]
# what is ambient off timer
# [(0, 1), (3, 1), (13, 1), (36, 1), (94, 1)]
# can i change the background color of ambient mode
# [(1, 1), (10, 1), (12, 1), (14, 1), (16, 1), (36, 1), (63, 1), (146, 1), (285, 1)]
# how do i select dynamic mode
# [(1, 1), (16, 1), (24, 1), (25, 1), (76, 1), (286, 1)]
# how do i select standard mode
# [(1, 1), (16, 1), (24, 1), (25, 1), (76, 1), (287, 1)]
# how do i select natural mode
# [(1, 1), (16, 1), (24, 1), (25, 1), (76, 1), (288, 1)]
# how do i select movie mode
# [(1, 1), (16, 1), (24, 1), (25, 1), (76, 1), (289, 1)]
# how do i configure backlight
# [(16, 1), (24, 1), (65, 1), (76, 1), (290, 1)]
# how do i configure brightness
# [(16, 1), (24, 1), (65, 1), (76, 1), (283, 1)]
# how do i configure contrast
# [(16, 1), (24, 1), (65, 1), (76, 1), (170, 1)]
# how do i configure sharpness
# [(16, 1), (24, 1), (65, 1), (76, 1), (291, 1)]
# how do i configure color
# [(16, 1), (24, 1), (65, 1), (76, 1), (146, 1)]
# how do i configure tint
# [(16, 1), (24, 1), (65, 1), (76, 1), (292, 1)]
# how do i configure apply picture settings
# [(16, 1), (24, 1), (65, 1), (67, 1), (76, 1), (110, 1), (293, 1)]
# how do i configure digital clean view
# [(16, 1), (18, 1), (24, 1), (65, 1), (76, 1), (294, 1), (295, 1)]
# how do i configure auto motion plus settings
# [(16, 1), (24, 1), (65, 1), (67, 1), (76, 1), (248, 1), (254, 1), (296, 1)]
# how do i configure local dimming
# [(16, 1), (24, 1), (65, 1), (76, 1), (297, 1), (298, 1)]
# how do i configure contrast enhancer
# [(16, 1), (24, 1), (65, 1), (76, 1), (170, 1), (299, 1)]
# how do i configure hdr mode
# [(1, 1), (16, 1), (24, 1), (65, 1), (76, 1), (300, 1)]
# how do i configure film mode
# [(1, 1), (16, 1), (24, 1), (65, 1), (76, 1), (301, 1)]
# how do i configure color tone
# [(16, 1), (24, 1), (65, 1), (76, 1), (146, 1), (302, 1)]
# how do i configure gamma
# [(16, 1), (24, 1), (65, 1), (76, 1), (303, 1)]
# how do i configure rgb only mode
# [(1, 1), (16, 1), (24, 1), (65, 1), (76, 1), (192, 1), (304, 1)]
# how do i configure color space settings
# [(16, 1), (24, 1), (65, 1), (67, 1), (76, 1), (146, 1), (305, 1)]
# how do i configure game motion plus
# [(16, 1), (24, 1), (65, 1), (76, 1), (254, 1), (296, 1), (306, 1)]
# how can i use hdmi uhd color
# [(14, 1), (16, 1), (24, 1), (35, 1), (146, 1), (307, 1), (308, 1)]
# how to adjust hdmi black level
# [(24, 1), (26, 1), (276, 1), (282, 1), (307, 1), (309, 1)]
# how to change the size of the picture to 169
# [(10, 1), (12, 2), (24, 1), (26, 2), (63, 1), (110, 1), (310, 1), (311, 1)]
# how to change the size of the picture to custom
# [(10, 1), (12, 2), (24, 1), (26, 2), (63, 1), (96, 1), (110, 1), (311, 1)]
# how to change the size of the picture to 43
# [(10, 1), (12, 2), (24, 1), (26, 2), (63, 1), (110, 1), (311, 1), (312, 1)]
# how to fit the picture to the screen
# [(12, 2), (24, 1), (26, 2), (42, 1), (110, 1), (313, 1)]
# how do i select standard sound mode
# [(1, 1), (2, 1), (16, 1), (24, 1), (25, 1), (76, 1), (287, 1)]
# how do i select optimized sound mode
# [(1, 1), (2, 1), (16, 1), (24, 1), (25, 1), (76, 1), (314, 1)]
# how do i amplify sound mode
# [(1, 1), (2, 1), (16, 1), (24, 1), (76, 1), (315, 1)]
# how do i balance the sound quality
# [(2, 1), (12, 1), (16, 1), (24, 1), (76, 1), (316, 1), (317, 1)]
# how do i change auto volume
# [(16, 1), (24, 1), (63, 1), (76, 1), (248, 1), (318, 1)]
# how do i select sound feedback
# [(2, 1), (16, 1), (24, 1), (25, 1), (76, 1), (319, 1)]
# how do i select speaker for sound output
# [(2, 1), (7, 1), (16, 1), (24, 1), (25, 1), (76, 1), (91, 1), (320, 1)]
# how do i connect to the bluetooth audio devices to the tv
# [(12, 2), (16, 1), (24, 1), (26, 2), (27, 1), (76, 1), (97, 1), (268, 1), (271, 1), (321, 1)]
# how do i set the current time on the tv
# [(12, 2), (15, 1), (16, 1), (24, 1), (27, 1), (41, 1), (76, 1), (178, 1), (196, 1)]
# in which cases do i need to reset the clock time
# [(12, 1), (16, 1), (26, 1), (30, 1), (51, 1), (76, 1), (78, 1), (95, 1), (178, 1), (322, 1), (323, 1)]
# how to set the clock automatically
# [(12, 1), (24, 1), (26, 1), (45, 1), (196, 1), (323, 1)]
# how to set time zone
# [(24, 1), (26, 1), (178, 1), (196, 1), (324, 1)]
# how to set daylight saving time dst
# [(24, 1), (26, 1), (178, 1), (196, 1), (325, 1), (326, 1), (327, 1)]
# how do i change the current time on tv
# [(12, 1), (15, 1), (16, 1), (24, 1), (27, 1), (41, 1), (63, 1), (76, 1), (178, 1)]
# how do i set the clock manually
# [(12, 1), (16, 1), (24, 1), (76, 1), (196, 1), (323, 1), (328, 1)]
# what are the steps to set sleep timer for the tv
# [(3, 1), (11, 1), (12, 2), (13, 1), (26, 1), (27, 1), (91, 1), (99, 1), (196, 1), (198, 1)]
# how do i turn off the tv using off timer
# [(12, 1), (13, 1), (16, 1), (24, 1), (27, 1), (37, 1), (61, 1), (76, 1), (94, 2)]
# how do i select ambient light detection
# [(16, 1), (24, 1), (25, 1), (36, 1), (76, 1), (329, 1), (330, 1)]
# how do i select minimum backlight
# [(16, 1), (24, 1), (25, 1), (76, 1), (290, 1), (331, 1)]
# how do i update tvs software through a usb device
# [(16, 1), (22, 1), (24, 1), (59, 1), (76, 1), (85, 1), (141, 1), (144, 1), (332, 1), (333, 1)]
# how do i update tvs software automatically
# [(16, 1), (24, 1), (45, 1), (76, 1), (85, 1), (141, 1), (144, 1)]
# what is the use of smart security
# [(0, 1), (3, 1), (10, 1), (12, 1), (33, 1), (35, 1), (334, 1)]
# how do i scan tv for malicious code
# [(16, 1), (24, 1), (27, 1), (76, 1), (91, 1), (266, 1), (335, 1), (336, 1)]
# where can i view bixby guide
# [(14, 1), (16, 1), (18, 1), (19, 1), (87, 1), (169, 1)]
# how to create new account
# [(24, 1), (26, 1), (52, 1), (54, 1), (58, 1)]
# where can i find experience points xp
# [(14, 1), (16, 1), (19, 1), (157, 1), (337, 1), (338, 1), (339, 1)]
# what is the feature of bixby guide
# [(0, 1), (3, 1), (10, 1), (12, 1), (34, 1), (87, 1), (169, 1)]
# what all things must be required to use the bixby function
# [(3, 1), (9, 1), (12, 1), (26, 1), (35, 1), (152, 1), (169, 1), (187, 1), (340, 1), (341, 1), (342, 1)]
# what are the requirements for using bixby
# [(3, 1), (12, 1), (61, 1), (91, 1), (99, 1), (169, 1), (343, 1)]
# where to view tvs software version
# [(18, 1), (19, 1), (26, 1), (141, 1), (144, 1), (344, 1)]
# how to update tvs software through internet
# [(24, 1), (26, 1), (66, 1), (85, 1), (141, 1), (144, 1), (332, 1)]
# how to update the tv automatically
# [(12, 1), (24, 1), (26, 1), (27, 1), (45, 1), (85, 1)]
# how to turn remote management on and off
# [(24, 1), (26, 1), (37, 1), (41, 1), (53, 1), (94, 1), (160, 1), (345, 1)]
# what is remote support
# [(0, 1), (3, 1), (160, 1), (346, 1)]
# where can i find the call center phone number
# [(12, 1), (14, 1), (16, 1), (19, 1), (157, 1), (347, 1), (348, 1), (349, 1), (350, 1)]
# can i request service i am having problem with the tv
# [(12, 1), (14, 1), (16, 2), (27, 1), (106, 1), (154, 1), (351, 1), (352, 1), (353, 1), (354, 1)]
# how to connect to internet network
# [(17, 1), (24, 1), (26, 2), (66, 1), (271, 1)]
# how to establishing a wired internet connection
# [(24, 1), (26, 1), (59, 1), (66, 1), (355, 1), (356, 1), (357, 1)]
# can i check the internet connection status
# [(12, 1), (14, 1), (16, 1), (66, 1), (188, 1), (207, 1), (355, 1)]
# how to reset network
# [(17, 1), (24, 1), (26, 1), (51, 1)]
# can i turn on the tv with a mobile device
# [(12, 1), (14, 1), (16, 1), (22, 1), (27, 1), (37, 1), (41, 1), (59, 1), (154, 1), (358, 1)]
# how to configure the ipv6 connection settings
# [(12, 1), (24, 1), (26, 1), (65, 1), (67, 1), (355, 1), (359, 1)]
# how to check the internet connection set up over ipv6
# [(12, 1), (24, 1), (26, 1), (66, 1), (143, 1), (188, 1), (196, 1), (355, 1), (359, 1), (360, 1)]
# can i changing the name of the tv on a network
# [(10, 1), (12, 2), (14, 1), (16, 1), (17, 1), (27, 1), (41, 1), (59, 1), (257, 1), (361, 1)]
# my ip auto setting failed how to configure it
# [(24, 1), (26, 1), (56, 1), (65, 1), (117, 1), (142, 1), (248, 1), (284, 1), (362, 1)]
# i am unable to connect to the network how to resolve
# [(12, 1), (16, 1), (17, 1), (24, 1), (26, 3), (106, 1), (271, 1), (363, 1), (364, 1)]
# how to check the dns values in ip settings
# [(12, 1), (24, 1), (26, 1), (30, 1), (67, 1), (188, 1), (362, 1), (365, 1), (366, 1)]
# can you explain connecting with a component cable
# [(6, 1), (8, 1), (14, 1), (59, 1), (154, 1), (252, 1), (367, 1), (368, 1)]
# how to how to connect and use external speakers
# [(23, 1), (24, 2), (26, 2), (35, 1), (53, 1), (271, 1), (369, 1)]
# how can i connect my mobile device to the tv
# [(12, 1), (14, 1), (16, 1), (22, 1), (24, 1), (26, 1), (27, 1), (56, 1), (271, 1), (358, 1)]
# how to connect to the tv via the smartthings app
# [(12, 2), (24, 1), (26, 2), (27, 1), (44, 1), (89, 1), (271, 1), (370, 1)]
# what is access notification
# [(0, 1), (3, 1), (167, 1), (203, 1)]
# how to change the input signal
# [(12, 1), (24, 1), (26, 1), (63, 1), (265, 1), (371, 1)]
# what is connection guide
# [(0, 1), (3, 1), (87, 1), (355, 1)]
# what is universal remote
# [(0, 1), (3, 1), (88, 1), (160, 1)]
# what are the connection notes for hdmi
# [(3, 1), (12, 1), (91, 1), (99, 1), (307, 1), (355, 1), (372, 1)]
# can you explain the connection notes for computers
# [(6, 1), (8, 1), (12, 1), (14, 1), (91, 1), (355, 1), (372, 1), (373, 1)]
# what are the connection notes for mobile devices
# [(3, 1), (12, 1), (91, 1), (97, 1), (99, 1), (355, 1), (358, 1), (372, 1)]
# how to pair the tv with the samsung smart remote
# [(12, 2), (24, 1), (26, 1), (27, 1), (33, 1), (57, 1), (154, 1), (160, 1), (374, 1)]
# how to delete the notifications
# [(12, 1), (24, 1), (26, 1), (69, 1), (93, 1)]
# where can i select the services which i want to be notified
# [(12, 1), (14, 1), (16, 2), (19, 1), (25, 1), (26, 1), (32, 1), (95, 1), (205, 1), (206, 1), (340, 1)]
# where do i find accessibility functions
# [(16, 1), (19, 1), (76, 1), (157, 1), (162, 1), (375, 1)]
# how do i activate voice guide
# [(16, 1), (24, 1), (76, 1), (87, 1), (155, 1), (211, 1)]
# how do i enable audio for video description function
# [(9, 1), (16, 1), (24, 1), (76, 1), (91, 1), (165, 1), (166, 1), (268, 1), (376, 1)]
# how do i enable high contrast
# [(16, 1), (24, 1), (76, 1), (170, 1), (171, 1), (376, 1)]
# how do i change tv screen to grayscale mode
# [(1, 1), (16, 1), (24, 1), (26, 1), (27, 1), (42, 1), (63, 1), (76, 1), (377, 1)]
# how do i invert the screen colors
# [(12, 1), (16, 1), (24, 1), (42, 1), (76, 1), (378, 1), (379, 1)]
# what is the function of learn tv remote
# [(0, 1), (3, 1), (9, 1), (10, 1), (12, 1), (27, 1), (158, 1), (160, 1)]
# where do i find caption settings
# [(16, 1), (19, 1), (67, 1), (76, 1), (157, 1), (380, 1)]
# how to select the caption language
# [(12, 1), (24, 1), (25, 1), (26, 1), (380, 1), (381, 1)]
# what is the function of digital caption
# [(0, 1), (3, 1), (9, 1), (10, 1), (12, 1), (295, 1), (380, 1)]
# how do i enabledisable light effect
# [(16, 1), (24, 1), (76, 1), (330, 1), (382, 1), (383, 1)]
# how do i select usage or retail mode
# [(1, 1), (16, 1), (24, 1), (25, 1), (76, 1), (123, 1), (384, 1), (385, 1)]
# how do i do factory reset
# [(16, 1), (24, 1), (51, 1), (76, 2), (386, 1)]
# how can i use remote management option
# [(14, 1), (16, 1), (24, 1), (35, 1), (159, 1), (160, 1), (345, 1)]
# what does remote support offer
# [(3, 1), (160, 1), (346, 1), (387, 1), (388, 1)]
# how do you do remote support
# [(8, 1), (24, 1), (76, 2), (160, 1), (346, 1)]
# how do i get information about the tv
# [(4, 1), (12, 1), (16, 1), (24, 1), (27, 1), (64, 1), (76, 1), (204, 1)]
# how can i request for service
# [(14, 1), (16, 1), (24, 1), (91, 1), (353, 1), (354, 1)]
# where do i find signal information
# [(16, 1), (19, 1), (64, 1), (76, 1), (157, 1), (265, 1)]
# how do i smart hub connection test
# [(16, 1), (24, 1), (29, 1), (33, 1), (50, 1), (76, 1), (355, 1)]
# how do i reset smart hub
# [(16, 1), (24, 1), (29, 1), (33, 1), (51, 1), (76, 1)]
# how do i do reset
# [(16, 1), (24, 1), (51, 1), (76, 2)]
# how can i fix the flickering and dimming issues
# [(12, 1), (14, 1), (16, 1), (24, 1), (53, 1), (113, 1), (297, 1), (389, 1), (390, 1)]
# how do i fix the screen color issues
# [(12, 1), (16, 1), (24, 1), (42, 1), (76, 1), (113, 1), (146, 1), (390, 1)]
# how do i fix screen brightness issues
# [(16, 1), (24, 1), (42, 1), (76, 1), (113, 1), (283, 1), (390, 1)]
# how do i fix blurring issues on tv screen
# [(16, 1), (24, 1), (27, 1), (41, 1), (42, 1), (76, 1), (113, 1), (390, 1), (391, 1)]
# how can i fix unwanted powering off issue
# [(14, 1), (16, 1), (24, 1), (94, 1), (113, 1), (392, 1), (393, 1), (394, 1)]
# how do i fix powering on issue
# [(16, 1), (24, 1), (41, 1), (76, 1), (113, 1), (392, 1), (393, 1)]
# what do i do if the channel is not found
# [(0, 1), (3, 1), (12, 1), (16, 1), (76, 2), (105, 1), (109, 1), (172, 1), (395, 1)]
# what do i do if picture is distorted
# [(0, 1), (3, 1), (16, 1), (76, 2), (105, 1), (110, 1), (396, 1)]
# how do i fix the missingwrong color issue
# [(12, 1), (16, 1), (24, 1), (76, 1), (113, 1), (146, 1), (392, 1), (397, 1)]
# how do i fix the poor color issue
# [(12, 1), (16, 1), (24, 1), (76, 1), (113, 1), (146, 1), (392, 1), (398, 1)]
# how do i fix dotted line issue on the edge of tv screen
# [(10, 1), (12, 1), (16, 1), (24, 1), (27, 1), (41, 1), (42, 1), (76, 1), (113, 1), (392, 1), (399, 1), (400, 1), (401, 1)]
# how do i fix black and white issue
# [(16, 1), (24, 1), (53, 1), (76, 1), (113, 1), (276, 1), (392, 1), (402, 1)]
# how do i fix low volume issue
# [(16, 1), (24, 1), (76, 1), (113, 1), (318, 1), (392, 1), (403, 1)]
# what can i do if picture is good but there is no sound with it
# [(0, 2), (2, 1), (3, 1), (14, 1), (16, 1), (76, 1), (105, 1), (110, 1), (117, 1), (131, 1), (133, 1), (154, 1), (404, 1), (405, 1)]
# what can i do if i hear no sound
# [(2, 1), (3, 1), (14, 1), (16, 2), (76, 1), (105, 1), (131, 1), (406, 1)]
# how do i fix odd sound of speaker
# [(2, 1), (10, 1), (16, 1), (24, 1), (76, 1), (113, 1), (320, 1), (407, 1)]
# how do i fix weak or no signal issue
# [(16, 1), (24, 1), (76, 1), (113, 1), (123, 1), (131, 1), (265, 1), (392, 1), (408, 1)]
# i am not getting captions for digital channels how to fix this
# [(16, 1), (24, 1), (26, 1), (79, 1), (91, 1), (103, 1), (106, 1), (109, 1), (113, 1), (115, 1), (184, 1), (295, 1)]
# what can i do if i am getting distorted picture on tv
# [(3, 1), (14, 1), (16, 2), (27, 1), (41, 1), (76, 1), (103, 1), (105, 1), (106, 1), (110, 1), (396, 1)]
# how do i fix low quality picture issue
# [(16, 1), (24, 1), (76, 1), (110, 1), (113, 1), (317, 1), (392, 1), (403, 1)]
# mode not supported message appears on my computer how do i fix this
# [(1, 1), (16, 1), (24, 1), (41, 1), (56, 1), (76, 1), (79, 1), (109, 1), (112, 1), (113, 1), (114, 1), (409, 1), (410, 1)]
# i am able to see the video but no audio is there in my computer how can i fix this
# [(0, 1), (12, 1), (14, 1), (16, 2), (24, 1), (26, 1), (30, 1), (56, 1), (79, 1), (106, 1), (113, 1), (131, 1), (133, 1), (166, 1), (222, 1), (268, 1), (404, 1), (409, 1), (411, 1)]
# what can i do if tv is not connecting to the network
# [(0, 1), (3, 1), (12, 1), (14, 1), (16, 1), (17, 1), (26, 1), (27, 1), (76, 1), (105, 1), (109, 1), (368, 1)]
# what do i do if wireless network connection failed
# [(3, 1), (16, 1), (17, 1), (76, 2), (105, 1), (142, 1), (355, 1), (412, 1)]
# wireless network signal is too weak how can i fix this
# [(0, 1), (14, 1), (16, 1), (17, 1), (24, 1), (79, 1), (113, 1), (265, 1), (408, 1), (412, 1), (413, 1)]
# schedule recording is not working how can i fix this issue
# [(0, 1), (14, 1), (16, 1), (24, 1), (79, 1), (109, 1), (113, 1), (175, 1), (177, 1), (392, 1), (414, 1)]
# anynet is not working what should i do
# [(0, 1), (3, 1), (16, 1), (76, 1), (109, 1), (118, 1), (414, 1), (415, 1)]
# how do i start anynet
# [(16, 1), (24, 1), (76, 1), (193, 1), (415, 1)]
# how do i exit anynet
# [(16, 1), (24, 1), (76, 1), (415, 1), (416, 1)]
# how do i fix connectingdisconnecting to anynet device which appears on screen
# [(16, 1), (22, 1), (24, 1), (26, 1), (41, 1), (42, 1), (76, 1), (95, 1), (112, 1), (113, 1), (415, 1), (417, 1)]
# anynet device wont play what should i do
# [(3, 1), (16, 1), (22, 1), (76, 1), (118, 1), (415, 1), (418, 1), (419, 1)]
# connected device is not displaying how can i fix this
# [(0, 1), (14, 1), (16, 1), (21, 1), (22, 1), (24, 1), (79, 1), (109, 1), (113, 1), (420, 1)]
# tv audio is not being played through the receiver what should i do
# [(0, 1), (3, 1), (12, 1), (16, 1), (27, 1), (76, 1), (109, 1), (118, 1), (268, 1), (332, 1), (421, 1), (422, 1), (423, 1)]
# how can i change the language from app
# [(12, 1), (14, 1), (16, 1), (24, 1), (44, 1), (63, 1), (80, 1), (381, 1)]
# how do i reset settings
# [(16, 1), (24, 1), (51, 1), (67, 1), (76, 1)]
# how do i reset picture
# [(16, 1), (24, 1), (51, 1), (76, 1), (110, 1)]
# how do i reset sound settings
# [(2, 1), (16, 1), (24, 1), (51, 1), (67, 1), (76, 1)]
# there is a notification icon in the tv screen what is the use of it on tv screen
# [(0, 2), (3, 1), (10, 1), (12, 2), (27, 2), (30, 1), (35, 1), (41, 1), (42, 2), (59, 1), (117, 1), (133, 1), (203, 1), (273, 1)]
# i want to know about settings option in smart hub what is it
# [(0, 1), (3, 1), (4, 1), (16, 1), (26, 1), (29, 1), (30, 1), (33, 1), (67, 1), (117, 1), (159, 1), (206, 1), (424, 1)]
# i want to know about source option in the smart hub what is it
# [(0, 1), (3, 1), (4, 1), (12, 1), (16, 1), (26, 1), (29, 1), (30, 1), (33, 1), (117, 1), (159, 1), (206, 1), (208, 1), (424, 1)]
# there is an apps option in the smart hub how can i use that
# [(0, 1), (12, 1), (14, 1), (16, 1), (20, 1), (24, 1), (28, 1), (29, 1), (30, 1), (33, 1), (35, 1), (111, 1), (133, 1), (159, 1)]
# i dont know about universal guide what is it
# [(0, 1), (3, 1), (4, 1), (16, 1), (87, 1), (88, 1), (117, 1), (424, 1), (425, 1)]
# i dont know about ambient mode can you explain briefly
# [(1, 1), (4, 1), (6, 1), (8, 1), (14, 1), (16, 1), (36, 1), (424, 1), (425, 1), (426, 1)]
# my tv screen becomes darker why
# [(27, 1), (42, 1), (56, 1), (121, 1), (427, 1), (428, 1)]
# my tv screen automatically became black screen how
# [(24, 1), (27, 1), (42, 2), (45, 1), (56, 1), (275, 1), (276, 1)]
# i want to  enter in to ambient mode when the tv is turned off how can i do that
# [(0, 1), (1, 1), (12, 1), (14, 1), (16, 2), (24, 1), (26, 2), (27, 1), (30, 1), (36, 1), (76, 1), (94, 1), (111, 1), (136, 1), (206, 1), (232, 1), (277, 1)]
# i to change the ambient mode settings how can i do that
# [(1, 1), (12, 1), (14, 1), (16, 2), (24, 1), (26, 1), (36, 1), (63, 1), (67, 1), (76, 1), (111, 1)]
# i want  to get information about weather how can i do that
# [(4, 1), (14, 1), (16, 2), (24, 1), (26, 1), (64, 1), (76, 1), (111, 1), (204, 1), (206, 1), (280, 1)]
# i to set wallpaper of the ambient mode screen how can i do that
# [(1, 1), (10, 1), (12, 1), (14, 1), (16, 2), (24, 1), (26, 1), (36, 1), (42, 1), (76, 1), (111, 1), (196, 1), (281, 1)]
# i want  to adjust the screen brightness can you explian about that
# [(4, 1), (8, 1), (12, 1), (14, 1), (16, 1), (26, 1), (42, 1), (111, 1), (206, 1), (282, 1), (283, 1), (429, 1)]
# i dont like the color of my tv screen how can i change the color
# [(10, 1), (12, 2), (14, 1), (16, 2), (24, 1), (27, 1), (42, 1), (56, 1), (63, 1), (146, 2), (425, 1), (430, 1)]
# i want to change the auto brightness setting how can i do that
# [(12, 1), (14, 1), (16, 2), (24, 1), (26, 1), (63, 1), (76, 1), (111, 1), (206, 1), (248, 1), (283, 1), (284, 1)]
# what is ambient off timer how can i use it
# [(0, 1), (3, 1), (13, 1), (14, 1), (16, 1), (24, 1), (35, 1), (36, 1), (94, 1), (117, 1)]
# how do i change the background color of ambient mode
# [(1, 1), (10, 1), (12, 1), (16, 1), (24, 1), (36, 1), (63, 1), (76, 1), (146, 1), (285, 1)]
# can i select standard mode
# [(1, 1), (14, 1), (16, 1), (25, 1), (287, 1)]
# can i select movie mode
# [(1, 1), (14, 1), (16, 1), (25, 1), (289, 1)]
# can i configure backlight
# [(14, 1), (16, 1), (65, 1), (290, 1)]
# can i configure brightness
# [(14, 1), (16, 1), (65, 1), (283, 1)]
# can i configure sharpness
# [(14, 1), (16, 1), (65, 1), (291, 1)]
# can i configure color
# [(14, 1), (16, 1), (65, 1), (146, 1)]
# can i configure tint
# [(14, 1), (16, 1), (65, 1), (292, 1)]
# can i configure apply picture settings
# [(14, 1), (16, 1), (65, 1), (67, 1), (110, 1), (293, 1)]
# can i configure digital clean view
# [(14, 1), (16, 1), (18, 1), (65, 1), (294, 1), (295, 1)]
# can i configure local dimming
# [(14, 1), (16, 1), (65, 1), (297, 1), (298, 1)]
# can i configure contrast enhancer
# [(14, 1), (16, 1), (65, 1), (170, 1), (299, 1)]
# can i configure hdr mode
# [(1, 1), (14, 1), (16, 1), (65, 1), (300, 1)]
# can i configure film mode
# [(1, 1), (14, 1), (16, 1), (65, 1), (301, 1)]
# can i configure color tone
# [(14, 1), (16, 1), (65, 1), (146, 1), (302, 1)]
# can i configure gamma
# [(14, 1), (16, 1), (65, 1), (303, 1)]
# can i configure rgb only mode
# [(1, 1), (14, 1), (16, 1), (65, 1), (192, 1), (304, 1)]
# can i configure color space settings
# [(14, 1), (16, 1), (65, 1), (67, 1), (146, 1), (305, 1)]
# can i configure reset picture
# [(14, 1), (16, 1), (51, 1), (65, 1), (110, 1)]
# i want to change game mode settings how to do this
# [(1, 1), (16, 1), (24, 1), (26, 2), (63, 1), (67, 1), (76, 1), (79, 1), (206, 1), (306, 1)]
# can i configure game motion plus
# [(14, 1), (16, 1), (65, 1), (254, 1), (296, 1), (306, 1)]
# i want to change the size of the picture to 169 how to do
# [(10, 1), (12, 2), (16, 1), (24, 1), (26, 3), (63, 1), (76, 1), (110, 1), (206, 1), (310, 1), (311, 1)]
# can i change the size of the picture to 43
# [(10, 1), (12, 2), (14, 1), (16, 1), (26, 1), (63, 1), (110, 1), (311, 1), (312, 1)]
# can i fit the picture to the screen
# [(12, 2), (14, 1), (16, 1), (26, 1), (42, 1), (110, 1), (313, 1)]
# can i adjust the picture size or position
# [(12, 1), (14, 1), (16, 1), (110, 1), (123, 1), (282, 1), (311, 1), (431, 1)]
# can i select standard sound mode
# [(1, 1), (2, 1), (14, 1), (16, 1), (25, 1), (287, 1)]
# can i select optimized sound mode
# [(1, 1), (2, 1), (14, 1), (16, 1), (25, 1), (314, 1)]
# what are the steps to amplify sound mode
# [(1, 1), (2, 1), (3, 1), (12, 1), (26, 1), (99, 1), (198, 1), (315, 1)]
# can i balance the sound quality
# [(2, 1), (12, 1), (14, 1), (16, 1), (316, 1), (317, 1)]
# can i change equalizer
# [(14, 1), (16, 1), (63, 1), (432, 1)]
# can i change hdmi input audio format
# [(14, 1), (16, 1), (63, 1), (268, 1), (307, 1), (371, 1), (433, 1)]
# can i configure digital output audio format
# [(7, 1), (14, 1), (16, 1), (65, 1), (268, 1), (295, 1), (433, 1)]
# can i balance the sound quality
# [(2, 1), (12, 1), (14, 1), (16, 1), (316, 1), (317, 1)]
# ...
# how do i get better audio quality what are the connections guidelines for it
# [(3, 1), (12, 1), (16, 1), (24, 1), (49, 1), (76, 1), (91, 1), (99, 1), (117, 1), (204, 1), (268, 1), (317, 1), (457, 1), (458, 1)]
# what is the connection notes for computers
# [(0, 1), (3, 1), (12, 1), (91, 1), (355, 1), (372, 1), (373, 1)]
# where do i find connection notes for mobile devices
# [(16, 1), (19, 1), (76, 1), (91, 1), (97, 1), (157, 1), (355, 1), (358, 1), (372, 1)]
# how to pair the tv with the samsung smart remote
# [(12, 2), (24, 1), (26, 1), (27, 1), (33, 1), (57, 1), (154, 1), (160, 1), (374, 1)]
# where do i find accessibility shortcuts functions
# [(16, 1), (19, 1), (76, 1), (157, 1), (162, 1), (164, 1), (375, 1)]
# can i enable audio for video description function
# [(9, 1), (14, 1), (16, 1), (91, 1), (165, 1), (166, 1), (268, 1), (376, 1)]
# where do i find the to enable high contrast
# [(12, 1), (16, 1), (19, 1), (26, 1), (76, 1), (157, 1), (170, 1), (171, 1), (376, 1)]
# can i change tv screen to grayscale mode
# [(1, 1), (14, 1), (16, 1), (26, 1), (27, 1), (42, 1), (63, 1), (377, 1)]
# can i invert the screen colors
# [(12, 1), (14, 1), (16, 1), (42, 1), (378, 1), (379, 1)]
# can i increase the font size
# [(12, 1), (14, 1), (16, 1), (311, 1), (459, 1), (460, 1)]
# what is the features of learn tv remote
# [(0, 1), (3, 1), (10, 1), (12, 1), (27, 1), (158, 1), (160, 1), (461, 1)]
# what is the features of learn menu screen
# [(0, 1), (3, 1), (10, 1), (12, 1), (42, 1), (158, 1), (161, 1), (461, 1)]
# how do i find caption settings
# [(16, 1), (24, 1), (67, 1), (76, 1), (157, 1), (380, 1)]
# can i select the caption language
# [(12, 1), (14, 1), (16, 1), (25, 1), (380, 1), (381, 1)]
# where do i find digital caption option
# [(16, 1), (19, 1), (76, 1), (157, 1), (159, 1), (295, 1), (380, 1)]
# how do i listen to the tv through bluetooth devices
# [(12, 1), (16, 1), (24, 1), (26, 1), (27, 1), (76, 1), (97, 1), (321, 1), (332, 1), (462, 1)]
# can i change the menu language option
# [(12, 1), (14, 1), (16, 1), (63, 1), (159, 1), (161, 1), (381, 1)]
# i want to enabledisable light effect how can i do this
# [(14, 1), (16, 2), (24, 1), (26, 1), (76, 1), (79, 1), (206, 1), (330, 1), (382, 1), (383, 1)]
# can i select usage or retail mode
# [(1, 1), (14, 1), (16, 1), (25, 1), (123, 1), (384, 1), (385, 1)]
# where do i find factory reset option
# [(16, 1), (19, 1), (51, 1), (76, 1), (157, 1), (159, 1), (386, 1)]
# i want to know the information about the tv how can i find this
# [(4, 1), (12, 2), (14, 1), (16, 2), (24, 1), (26, 1), (27, 1), (64, 1), (79, 1), (157, 1), (206, 1), (424, 1)]
# can i request for service
# [(14, 1), (16, 1), (91, 1), (353, 1), (354, 1)]
# can i troubleshoot video issues
# [(14, 1), (16, 1), (166, 1), (390, 1), (463, 1)]
# can i troubleshoot sound issues
# [(2, 1), (14, 1), (16, 1), (390, 1), (463, 1)]
# how do i know the signal information
# [(12, 1), (16, 1), (24, 1), (64, 1), (76, 1), (265, 1), (424, 1)]
# can i do smart hub connection test
# [(14, 1), (16, 1), (29, 1), (33, 1), (50, 1), (76, 1), (355, 1)]
# can i do reset smart hub
# [(14, 1), (16, 1), (29, 1), (33, 1), (51, 1), (76, 1)]
# where do i find reset option
# [(16, 1), (19, 1), (51, 1), (76, 1), (157, 1), (159, 1)]
# can i fix the flickering and dimming issues
# [(12, 1), (14, 1), (16, 1), (53, 1), (113, 1), (297, 1), (389, 1), (390, 1)]
# can i fix the screen color issues
# [(12, 1), (14, 1), (16, 1), (42, 1), (113, 1), (146, 1), (390, 1)]
# can i fix screen brightness issues
# [(14, 1), (16, 1), (42, 1), (113, 1), (283, 1), (390, 1)]
# what are the steps to fix blurring issues on tv screen
# [(3, 1), (12, 1), (26, 1), (27, 1), (41, 1), (42, 1), (99, 1), (113, 1), (198, 1), (390, 1), (391, 1)]
# how do i fix unwanted powering off issue
# [(16, 1), (24, 1), (76, 1), (94, 1), (113, 1), (392, 1), (393, 1), (394, 1)]
# can i fix powering on issue
# [(14, 1), (16, 1), (41, 1), (113, 1), (392, 1), (393, 1)]
# i am getting channel is not found error how to fix this
# [(0, 1), (16, 1), (24, 1), (26, 1), (79, 1), (103, 1), (106, 1), (109, 1), (113, 1), (172, 1), (395, 1), (450, 1)]
# what can i do if picture is distorted
# [(0, 1), (3, 1), (14, 1), (16, 1), (76, 1), (105, 1), (110, 1), (396, 1)]
# can i fix the missingwrong color issue
# [(12, 1), (14, 1), (16, 1), (113, 1), (146, 1), (392, 1), (397, 1)]
# can i fix the poor color issue
# [(12, 1), (14, 1), (16, 1), (113, 1), (146, 1), (392, 1), (398, 1)]
# can i fix dotted line issue on the edge of tv screen
# [(10, 1), (12, 1), (14, 1), (16, 1), (27, 1), (41, 1), (42, 1), (113, 1), (392, 1), (399, 1), (400, 1), (401, 1)]
# can i fix black and white issue
# [(14, 1), (16, 1), (53, 1), (113, 1), (276, 1), (392, 1), (402, 1)]
# can i fix low volume issue
# [(14, 1), (16, 1), (113, 1), (318, 1), (392, 1), (403, 1)]
# what to do if i hear no sound
# [(2, 1), (3, 1), (16, 1), (26, 1), (76, 1), (105, 1), (131, 1), (406, 1)]
# can i fix odd sound of speaker
# [(2, 1), (10, 1), (14, 1), (16, 1), (113, 1), (320, 1), (407, 1)]
# can i fix weak or no signal issue
# [(14, 1), (16, 1), (113, 1), (123, 1), (131, 1), (265, 1), (392, 1), (408, 1)]
# my tv is not receiving channels what should i do
# [(0, 1), (3, 1), (16, 1), (27, 1), (56, 1), (76, 1), (109, 1), (118, 1), (184, 1), (464, 1)]
# is there any way i can get captions for digital channels
# [(0, 1), (14, 1), (16, 1), (91, 1), (115, 1), (133, 1), (174, 1), (184, 1), (204, 1), (221, 1), (295, 1)]
# i am getting distorted picture on tv how to fix this issue
# [(16, 1), (24, 1), (26, 1), (27, 1), (41, 1), (79, 1), (103, 1), (106, 1), (110, 1), (113, 1), (392, 1), (396, 1)]
# tv is not connecting to the network what should i do
# [(0, 1), (3, 1), (12, 1), (16, 1), (17, 1), (26, 1), (27, 1), (76, 1), (109, 1), (118, 1), (368, 1)]
# wireless network connection failed how can i fix this
# [(14, 1), (16, 1), (17, 1), (24, 1), (79, 1), (113, 1), (142, 1), (355, 1), (412, 1)]
# what can i do when wireless network signal is too weak
# [(0, 1), (3, 1), (14, 1), (16, 1), (17, 1), (76, 1), (232, 1), (265, 1), (408, 1), (412, 1), (413, 1)]
# what can i do if schedule recording is not working
# [(0, 1), (3, 1), (14, 1), (16, 1), (76, 1), (105, 1), (109, 1), (175, 1), (177, 1), (414, 1)]
# what is source and how to serch data for channels
# [(0, 1), (3, 1), (24, 1), (26, 1), (53, 1), (91, 1), (184, 1), (208, 1), (465, 1), (466, 1)]
# how to install app and how to use universal guide
# [(24, 2), (26, 2), (35, 1), (44, 1), (53, 1), (74, 1), (87, 1), (88, 1)]
# why my screen getting darker and also sometimes in state of black screen
# [(10, 1), (30, 1), (42, 2), (53, 1), (56, 1), (103, 1), (121, 1), (276, 1), (428, 1), (467, 1), (468, 1), (469, 1)]
# what is decor and how to set wallpaper of the ambient mode screen
# [(0, 1), (1, 1), (3, 1), (10, 1), (12, 1), (24, 1), (26, 1), (36, 1), (42, 1), (53, 1), (196, 1), (281, 1), (470, 1)]
# how to adjust the brightness and color of the screen
# [(10, 1), (12, 2), (24, 1), (26, 1), (42, 1), (53, 1), (146, 1), (282, 1), (283, 1)]
# what are the features of auto brightness and ambient off timer
# [(3, 1), (10, 1), (12, 1), (13, 1), (36, 1), (53, 1), (94, 1), (99, 1), (248, 1), (283, 1), (461, 1)]
# how to sign in to samsung account and what is bixby guide
# [(0, 1), (3, 1), (24, 1), (26, 2), (30, 1), (52, 1), (53, 1), (57, 1), (71, 1), (87, 1), (169, 1)]
# how to change the voice style of bixby and what is the use of user information
# [(0, 1), (3, 1), (10, 2), (12, 2), (24, 1), (26, 1), (35, 1), (53, 1), (63, 1), (64, 1), (155, 1), (169, 1), (471, 1), (472, 1)]
# can i update software through internet and through usb device
# [(14, 1), (16, 1), (22, 1), (53, 1), (66, 1), (85, 1), (144, 1), (332, 2), (333, 1)]
# what is remote support and how it works
# [(0, 1), (3, 1), (24, 1), (53, 1), (117, 1), (160, 1), (346, 1), (473, 1)]
# how to establish wireless internet connection and how to check the internet connection
# [(12, 1), (24, 2), (26, 2), (53, 1), (66, 2), (188, 1), (355, 2), (412, 1), (448, 1)]
# how to configure failed ip auto setting and i am unable to connect to the network how to fix this
# [(12, 1), (16, 1), (17, 1), (24, 2), (26, 4), (53, 1), (65, 1), (79, 1), (106, 1), (113, 1), (142, 1), (248, 1), (271, 1), (284, 1), (362, 1), (364, 1)]
# what are dynamic and standard mode
# [(1, 1), (3, 1), (53, 1), (99, 1), (286, 1), (287, 1)]
# what are natural and movie mode
# [(1, 1), (3, 1), (53, 1), (99, 1), (288, 1), (289, 1)]
# where can i get digital output audio format and sound mirroring
# [(2, 1), (7, 1), (14, 1), (16, 1), (19, 1), (53, 1), (204, 1), (268, 1), (295, 1), (433, 1), (454, 1)]
# can i remove the registered channels and add back the removed channels
# [(12, 2), (14, 1), (16, 1), (53, 1), (75, 1), (184, 2), (256, 1), (263, 1), (455, 1), (474, 1)]
# how to configure backlight and brightness
# [(24, 1), (26, 1), (53, 1), (65, 1), (283, 1), (290, 1)]
# how to configure contrast and sharpness
# [(24, 1), (26, 1), (53, 1), (65, 1), (170, 1), (291, 1)]
# how do i configure tint and apply picture settings
# [(16, 1), (24, 1), (53, 1), (65, 1), (67, 1), (76, 1), (110, 1), (292, 1), (293, 1)]
# how do i configure white balance and gamma
# [(16, 1), (24, 1), (53, 1), (65, 1), (76, 1), (303, 1), (316, 1), (402, 1)]
# how do i configure rgb only mode and color space settings
# [(1, 1), (16, 1), (24, 1), (53, 1), (65, 1), (67, 1), (76, 1), (146, 1), (192, 1), (304, 1), (305, 1)]
# where to select time zone and how to adjusts for daylight saving time
# [(19, 1), (24, 1), (25, 1), (26, 2), (53, 1), (91, 1), (178, 2), (324, 1), (325, 1), (327, 1), (475, 1)]
# how to change the current time and set the clock manually
# [(12, 2), (15, 1), (24, 1), (26, 1), (53, 1), (63, 1), (178, 1), (196, 1), (323, 1), (328, 1)]
# how to use the sleep timer and turn off the tv using the off timer
# [(11, 1), (12, 3), (13, 2), (24, 1), (26, 1), (27, 1), (35, 1), (37, 1), (53, 1), (61, 1), (94, 2)]
# what is ambient light detection and minimum backlight
# [(0, 1), (3, 1), (36, 1), (53, 1), (290, 1), (329, 1), (330, 1), (331, 1)]
# what is power saving mode and motion lighting
# [(0, 1), (1, 1), (3, 1), (53, 1), (296, 1), (327, 1), (439, 1), (476, 1)]
# what is default  cc1  cc4 text1  text4 and default  service1  service6  cc1  cc4  text1  text4
# [(0, 1), (3, 1), (53, 1), (477, 2), (478, 2), (479, 2), (480, 1), (481, 1), (482, 2), (483, 2)]
# how can i connect my samsungsmartremote to tv automatically and if it is not connected what will i do
# [(0, 1), (3, 1), (14, 1), (16, 2), (21, 1), (24, 1), (26, 1), (27, 1), (45, 1), (53, 1), (56, 1), (76, 1), (105, 1), (109, 1), (117, 1), (149, 1), (271, 1), (272, 1)]
# how to select air or cable as the dtv mode and what is the use of tv plus
# [(0, 1), (1, 1), (3, 1), (10, 1), (12, 2), (24, 1), (25, 1), (26, 1), (27, 1), (35, 1), (53, 1), (123, 1), (189, 1), (251, 1), (252, 1), (253, 1), (254, 1)]
# how do i record using time timeshift function and how to go to the live tv
# [(9, 1), (12, 1), (16, 1), (24, 2), (26, 2), (27, 1), (53, 1), (61, 1), (76, 1), (178, 1), (194, 1), (216, 1), (240, 1), (241, 1)]
# how do i stop recording  stop timeshift and how do i get the information of recorded program
# [(10, 1), (12, 1), (16, 2), (24, 2), (53, 1), (64, 1), (76, 2), (173, 1), (177, 1), (179, 2), (194, 1), (197, 1), (204, 1)]
# how to do slow forward or slow rewind and how can i jump forward  jump backward
# [(14, 1), (16, 1), (24, 2), (26, 1), (53, 1), (76, 1), (123, 1), (242, 2), (243, 1), (244, 2), (245, 1), (246, 2)]
# explain the steps how to do schedule recording while watching a program and explain the steps how to do schedule recording while watching a program
# [(6, 2), (12, 2), (24, 2), (26, 2), (53, 1), (59, 2), (76, 2), (173, 2), (175, 2), (177, 2), (198, 2), (227, 2), (228, 2)]
# please instruct how to record any program and is there any way to stop the recording
# [(0, 1), (12, 1), (24, 1), (26, 2), (53, 1), (133, 1), (173, 1), (174, 2), (177, 1), (179, 1), (214, 1), (215, 1), (216, 1), (221, 1)]
# please provide some instructions on how to schedule program and also can you please explain how to schedule recording
# [(6, 1), (8, 1), (14, 1), (24, 2), (26, 2), (41, 1), (53, 1), (173, 1), (175, 2), (177, 1), (215, 2), (217, 1), (218, 1), (219, 1), (467, 1)]
# please explain the procedure how to edit recording time and explain the procedure for cancelling scheduled viewing  scheduled recording
# [(6, 2), (12, 2), (24, 1), (26, 1), (53, 1), (91, 1), (176, 1), (177, 2), (178, 1), (181, 2), (182, 1), (215, 1), (220, 2), (484, 1)]
# how can i select channel filter option and how can i change antenna type
# [(14, 2), (16, 2), (24, 2), (25, 1), (53, 1), (63, 1), (159, 1), (172, 1), (223, 1), (224, 1), (225, 1)]
# how do i troubleshoot video issues and how do i troubleshoot sound issues
# [(2, 1), (16, 2), (24, 2), (53, 1), (76, 2), (166, 1), (390, 2), (463, 2)]
# where do i find signal information and how do i smart hub connection test
# [(16, 2), (19, 1), (24, 1), (29, 1), (33, 1), (50, 1), (53, 1), (64, 1), (76, 2), (157, 1), (265, 1), (355, 1)]
# how do i reset smart hub and how do i do reset
# [(16, 2), (24, 2), (29, 1), (33, 1), (51, 2), (53, 1), (76, 3)]
# how do i use voice guide and how do i select high contrast
# [(16, 2), (24, 2), (25, 1), (35, 1), (53, 1), (76, 2), (87, 1), (155, 1), (170, 1), (171, 1)]
# where do i find the option of learn tv remote and where do i find the option of learn menu screen
# [(10, 2), (12, 2), (16, 2), (19, 2), (27, 1), (42, 1), (53, 1), (76, 2), (157, 2), (158, 2), (159, 2), (160, 1), (161, 1)]
# how do i turn on voice guide using bixby and how do i turn on video description using bixby
# [(16, 2), (24, 2), (37, 2), (41, 2), (53, 1), (61, 2), (76, 2), (87, 1), (155, 1), (165, 1), (166, 1), (169, 2)]
# how do i start recording and what is timeshift
# [(0, 1), (3, 1), (16, 1), (24, 1), (53, 1), (76, 1), (177, 1), (193, 1), (194, 1)]
# how do i stop recording and where do i find information about my program
# [(4, 1), (16, 2), (19, 1), (24, 1), (53, 1), (56, 1), (64, 1), (76, 2), (157, 1), (173, 1), (177, 1), (179, 1)]
# can i enlarge my tv screen
# [(14, 1), (16, 1), (27, 1), (42, 1), (56, 1), (156, 1)]
# can i activate the caption function
# [(9, 1), (12, 1), (14, 1), (16, 1), (211, 1), (380, 1)]
# is it possible to turn tv in ambient mode
# [(0, 1), (1, 1), (26, 1), (27, 1), (30, 1), (36, 1), (37, 1), (117, 1), (485, 1)]
# can i test the smart hub connections
# [(12, 1), (14, 1), (16, 1), (29, 1), (33, 1), (49, 1), (50, 1)]
# can i create and manage my samsung account
# [(14, 1), (16, 1), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1)]
# can i create a samsung account using a paypal account
# [(14, 1), (16, 1), (52, 2), (54, 1), (57, 1), (59, 2), (61, 1), (62, 1)]
# can i change the information to a samsung account
# [(12, 1), (14, 1), (16, 1), (26, 1), (52, 1), (57, 1), (59, 1), (63, 1), (64, 1)]
# can i view privacy policy
# [(14, 1), (16, 1), (18, 1), (72, 1), (73, 1)]
# can i check app details
# [(14, 1), (16, 1), (44, 1), (183, 1), (188, 1)]
# can i update apps automatically
# [(14, 1), (16, 1), (28, 1), (45, 1), (85, 1)]
# can i turn off notifications
# [(14, 1), (16, 1), (37, 1), (93, 1), (94, 1)]
# can i turn on voice guide using bixby
# [(14, 1), (16, 1), (37, 1), (41, 1), (61, 1), (87, 1), (155, 1), (169, 1)]
# can i turn on high contrast using bixby
# [(14, 1), (16, 1), (37, 1), (41, 1), (61, 1), (169, 1), (170, 1), (171, 1)]
# can i cancel scheduled viewing  cancel scheduled recording
# [(14, 1), (16, 1), (177, 1), (180, 2), (181, 2), (182, 1)]
# is my samsung smart remote automatically pairs to the tv
# [(0, 1), (12, 1), (26, 1), (27, 1), (33, 1), (45, 1), (56, 1), (57, 1), (160, 1), (486, 1)]
# is it possible to install different apps using smart hub in my tv
# [(0, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (33, 1), (56, 1), (61, 1), (74, 1), (117, 1), (209, 1), (485, 1)]
# can i change the content and settings for ambient mode
# [(1, 1), (12, 1), (14, 1), (16, 1), (36, 1), (53, 1), (63, 1), (67, 1), (91, 1), (212, 1)]
# can i connect various external devices to my tv
# [(14, 1), (16, 1), (23, 1), (26, 1), (27, 1), (56, 1), (97, 1), (271, 1), (487, 1)]
#
#
#  signal information under self diagnosis isnt activated how do i activate that
#  [(16, 1), (24, 1), (64, 1), (76, 1), (111, 1), (211, 1), (265, 1), (441, 1)]

# %% [markdown]
# # Cosine Similarity
#
# ##### BOW representation did not do very well and retrieved the wrong answer since it is looking for exact word match which is very rare in real life scenarios.

# %%
import sklearn
from sklearn.metrics.pairwise import cosine_similarity

def retrieveAndPrintAnswer(question_embedding,sentence_embeddings,eManualdf,sentences):
    max_sim=-1
    index_sim=-1
    for index,eManual_embedding in enumerate(sentence_embeddings):
        sim=cosine_similarity(eManual_embedding,question_embedding)[0][0]
        print(index, sim, sentences[index])
        if sim>max_sim:
            max_sim=sim
            index_sim=index
    
    print("\n")
    print("Question: ",question)
    print("\n")
    print("Retrieved: ", eManualdf.iloc[index_sim,0]) 
    print("Answer: ", eManualdf.iloc[index_sim,1])        
    
retrieveAndPrintAnswer(question_embedding,bow_corpus,df,sentences)
# Out:
# 0 0.06237828615518053 what is sound mode
# 1 0.9205817818752566 could you explain about sound output
# 2 0.06237828615518053 what is the function of sleep timer
# 3 0.9997852982986982 where can i can view the current network
# 4 0.9997852982986982 how to select an external device connected to the tv
# 5 0.9997852982986982 where can i search the apps in smart hub services
# 6 0.9993063048340446 how to use the feature of apps
# 7 0.7498378553650925 how to turn tv in ambient mode
# 8 0.9997852982986982 how to move item on the home screen
# 9 0.9988367534372583 how to turn on the autorun smart hub function
# 10 0.9997852982986982 how to launch the last used app automatically
# 11 0.9997852982986982 how to test the smart hub connections
# 12 0.9997841818782067 how to reset smart hub
# 13 0.9997841818782067 how to create and manage my samsung account
# 14 0.9997841818782067 how to create new account
# 15 0.9997841818782067 how to create a samsung account using a facebook account
# 16 0.9999604961681129 can i create a samsung account using a paypal account
# 17 0.9997852982986982 how to change the information to a samsung account
# 18 0.9997852982986982 how to configure the sync internet settings
# 19 0.9997841818782067 how to delete samsung account
# 20 0.9993063048340446 how to sign out of samsung account
# 21 0.9999760547866449 where to view privacy policy
# 22 0.9997841818782067 how to install app
# 23 0.9999223700424824 how to delete an app
# 24 0.9997852982986982 how to add apps to the home screen
# 25 0.9999999999999999 i need to lock app how to do this
# 26 0.9997841818782067 how to move app from one location to other
# 27 0.9997841818782067 how to reinstall apps
# 28 0.9997841818782067 how to update apps automatically
# 29 0.9997841818782067 how to rate apps
# 30 0.06237828615518053 what is the use of universal guide
# 31 0.06237828615518053 what is smartthings
# 32 0.9997841818782067 how to select location list in smart
# 33 0.9997841818782067 how to create new account in smartthings
# 34 0.9999604961681129 for which items can i turn off notifications
# 35 0.7498378553650925 can i create custom mode
# 36 0.9993063048340446 where can i view list of the connected smart devices
# 37 0.9997852982986982 how to launch the emanual
# 38 0.9665615578617778 what are the uses of buttons in the emanual
# 39 0.9997841818782067 how to surf internet on my tv
# 40 0.06237828615518053 what can i do if my tv is getting hot
# 41 0.9980825675929894 i am not getting full display picture how do i do that
# 42 0.7498378553650925 mode not supported appears on screen how to fix this
# 43 0.06237828615518053 the captions in the tv is grayed out how should i fix it
# 44 0.9993063048340446 why the tv smells of plastic
# 45 0.06237828615518053 why the stand is wobbly or crooked
# 46 0.9988367534372583 why the broadcasting function has been deactivated
# 47 0.06237828615518053 why there is no pip available
# 48 0.06237828615518053 why my settings are lost everytime the tv is turned off
# 49 0.9997852982986982 why this pop tvs internal banner ad appears on the screen how do i change this
# 50 0.9997852982986982 my software update over the internet has failed how do i fix this
# 51 0.9999999999999999 how do i rotate my samsung tv screen
# 52 0.9665615578617778 what will happen if i press the color buttons
# 53 0.9665615578617778 what are the things we can do with playpause button
# 54 0.9999999999999999 how do i use voice guide
# 55 0.9999999999999999 how do i enlarge screen
# 56 0.9993063048340446 where do i find the option of learn tv remote
# 57 0.9993063048340446 where do i find the option of learn menu screen
# 58 0.9997852982986982 how do i open the accessibility shortcuts menu
# 59 0.9997852982986982 how do i turn on the voice guide
# 60 0.9999999999999999 how do i turn on video description
# 61 0.9997852982986982 how do i access the main accessibility menu to change voice guide settings
# 62 0.9999999999999999 how do i turn on voice guide using bixby
# 63 0.9999999999999999 how do i turn on video description using bixby
# 64 0.9999999999999999 how do i turn on high contrast using bixby
# 65 0.9997852982986982 how do i turn on the tv using voice
# 66 0.9999999999999999 how do i change channel
# 67 0.9999604961681129 how can i view program information
# 68 0.9999604961681129 how can i schedule any program
# 69 0.9999604961681129 how can i edit recording time
# 70 0.9997852982986982 how can i stop the recording
# 71 0.9999999999999999 how do i cancel scheduled viewing  cancel scheduled recording
# 72 0.9993063048340446 where do i find the details of program
# 73 0.9993063048340446 where do i find the list of my favorite channels
# 74 0.9999999999999999 where do i find guide screen option
# 75 0.9999999999999999 where do i find program info screen
# 76 0.9997852982986982 how do i cancel scheduled view from the guide
# 77 0.9993063048340446 where do i check the list of my all channels
# 78 0.9993063048340446 how can i check the list of my favorite channels
# 79 0.9997841818782067 how to register channels as favorite
# 80 0.9997841818782067 how to add channels to favorite list
# 81 0.9997841818782067 how to delete channels from favorite list
# 82 0.9999604961681129 how can i view and select channels on my favorite lists only
# 83 0.9999999999999999 how do i start recording
# 84 0.06237828615518053 what is timeshift
# 85 0.9999999999999999 how do i stop recording
# 86 0.9833821803872265 where do i find information about my program
# 87 0.9993063048340446 how do i set length of recording time
# 88 0.9999604961681129 where can i find my recorded program
# 89 0.9665615578617778 what are the steps to delete the recorded program
# 90 0.9999999999999999 how do i open channel list
# 91 0.9999999999999999 where do i find schedule manager or recordings
# 92 0.9999604961681129 how can i view which program i watched recently
# 93 0.9999999999999999 how do i delete notification
# 94 0.9980825675929894 how do i select services that i want to get notified
# 95 0.7498378553650925 how to change the picture mode
# 96 0.7498378553650925 how to change the sound mode
# 97 0.9205817818752566 how to change the sound output
# 98 0.9997852982986982 how can i check the current network and internet status
# 99 0.9997852982986982 how can i change the source
# 100 0.7498378553650925 what are the different types of things we can do in ambient mode
# 101 0.9999999999999999 where do i find emanual
# 102 0.9999999999999999 how do i activate bixby
# 103 0.9997852982986982 how to delete the recorded content
# 104 0.9665615578617778 what are the precautions for bixby
# 105 0.9997841818782067 please instruct how to record any program
# 106 0.9997841818782067 please provide some instructions on how to schedule program
# 107 0.9947279261542804 can you please explain how to schedule recording
# 108 0.9947279261542804 please explain the procedure how to edit recording time
# 109 0.06237828615518053 is there any way to stop the recording
# 110 0.9999604961681129 from where i can see program information
# 111 0.9999604961681129 how can i select channel filter option
# 112 0.9999604961681129 how can i change antenna type
# 113 0.9999604961681129 from where i can check schedule manager option
# 114 0.9997852982986982 how do i do instant recording from the guide screen
# 115 0.9947279261542804 explain the steps how to do schedule recording from the guide screen
# 116 0.9947279261542804 explain the steps how to do schedule recording while watching a program
# 117 0.9947279261542804 explain the steps how to do schedule recording while watching a program
# 118 0.9997852982986982 how can i schedule recording when the date and time are already entered
# 119 0.9999604961681129 how can i manage recording list
# 120 0.9999604961681129 how can i delete schedule recordings
# 121 0.9997852982986982 where can i find the recording list
# 122 0.9999604961681129 how can i start early recording
# 123 0.9999604961681129 how can i continue recording even after program ended
# 124 0.9999999999999999 how do i edit scheduled viewing
# 125 0.9999999999999999 how do i set scheduled viewing time
# 126 0.9997841818782067 how to cancel sheduled viewing
# 127 0.9999999999999999 how do i check scheduled viewings
# 128 0.9988367534372583 how do i record using time timeshift function
# 129 0.9997852982986982 how to go to the live tv
# 130 0.9999999999999999 how do i stop recording  stop timeshift
# 131 0.9997841818782067 how to do slow forward or slow rewind
# 132 0.9999604961681129 how can i jump forward  jump backward
# 133 0.9999604961681129 how can i do fast forward  rewind
# 134 0.999991391443956 how do i lock a current channel
# 135 0.9988367534372583 how can i view the channels that are serached by auto program function
# 136 0.7498378553650925 how to select air or cable as the dtv mode
# 137 0.06237828615518053 what is the use of tv plus
# 138 0.9999999999999999 how do i add removed channels again
# 139 0.9997841818782067 how to rename channel name
# 140 0.9997852982986982 how do i watch the blocked or restricted channels
# 141 0.9665615578617778 what are the steps to register channels as favorites
# 142 0.9999999999999999 how do i select and view channels from favorite list only
# 143 0.9999999999999999 how do i edit favorites list
# 144 0.9997841818782067 how to add channels to favorites list
# 145 0.9997841818782067 how to remove channels from favorites list
# 146 0.9999999999999999 how do i rearrange my favorites list
# 147 0.9997852982986982 how to change the broadcasting signal
# 148 0.9997841818782067 how to scan for available channels
# 149 0.9999999999999999 hpw do i configure advanced broadcasting audio settings
# 150 0.9205817818752566 where do i find multitrack sound option
# 151 0.9999604961681129 how can i connect samsungsmartremote to tv
# 152 0.06237828615518053 what is the use of notification icon on tv screen
# 153 0.06237828615518053 what is settings option in the smart hub
# 154 0.06237828615518053 what is source option in the smart hub
# 155 0.06237828615518053 what is the use of search option in tne smart hub
# 156 0.06237828615518053 what is the use of apps option in the smart hub
# 157 0.7498378553650925 how can i turn on ambient mode on tv screen
# 158 0.06237828615518053 what is universal guide
# 159 0.7498378553650925 can you explain ambient mode
# 160 0.9997841818782067 how my tv screen became black screen
# 161 0.06237828615518053 can i enter to ambient mode when the tv is turned off
# 162 0.7498378553650925 how to change the ambient mode settings
# 163 0.9999604961681129 from where i can select beautiful screens
# 164 0.9833821803872265 how to get information about weather
# 165 0.7498378553650925 how can i to set wallpaper of the ambient mode screen
# 166 0.9997852982986982 how to adjust the screen brightness
# 167 0.9997852982986982 how to change the auto brightness setting
# 168 0.06237828615518053 what is ambient off timer
# 169 0.7498378553650925 can i change the background color of ambient mode
# 170 0.7498378553650925 how do i select dynamic mode
# 171 0.7498378553650925 how do i select standard mode
# 172 0.7498378553650925 how do i select natural mode
# 173 0.7498378553650925 how do i select movie mode
# 174 0.9999999999999999 how do i configure backlight
# 175 0.9999999999999999 how do i configure brightness
# 176 0.9999999999999999 how do i configure contrast
# 177 0.9999999999999999 how do i configure sharpness
# 178 0.9999999999999999 how do i configure color
# 179 0.9999999999999999 how do i configure tint
# 180 0.9999999999999999 how do i configure apply picture settings
# 181 0.9999999999999999 how do i configure digital clean view
# 182 0.9999999999999999 how do i configure auto motion plus settings
# 183 0.9999999999999999 how do i configure local dimming
# 184 0.9999999999999999 how do i configure contrast enhancer
# 185 0.7498378553650925 how do i configure hdr mode
# 186 0.7498378553650925 how do i configure film mode
# 187 0.9999999999999999 how do i configure color tone
# 188 0.9999999999999999 how do i configure gamma
# 189 0.7498378553650925 how do i configure rgb only mode
# 190 0.9999999999999999 how do i configure color space settings
# 191 0.9999999999999999 how do i configure game motion plus
# 192 0.9999604961681129 how can i use hdmi uhd color
# 193 0.9997841818782067 how to adjust hdmi black level
# 194 0.9993063048340446 how to change the size of the picture to 169
# 195 0.9993063048340446 how to change the size of the picture to custom
# 196 0.9993063048340446 how to change the size of the picture to 43
# 197 0.9947279261542804 how to fit the picture to the screen
# 198 0.7498378553650925 how do i select standard sound mode
# 199 0.7498378553650925 how do i select optimized sound mode
# 200 0.7498378553650925 how do i amplify sound mode
# 201 0.9205817818752566 how do i balance the sound quality
# 202 0.9999999999999999 how do i change auto volume
# 203 0.9205817818752566 how do i select sound feedback
# 204 0.9205817818752566 how do i select speaker for sound output
# 205 0.9947279261542804 how do i connect to the bluetooth audio devices to the tv
# 206 0.9947279261542804 how do i set the current time on the tv
# 207 0.9997852982986982 in which cases do i need to reset the clock time
# 208 0.9997852982986982 how to set the clock automatically
# 209 0.9997841818782067 how to set time zone
# 210 0.9997841818782067 how to set daylight saving time dst
# 211 0.9997852982986982 how do i change the current time on tv
# 212 0.9997852982986982 how do i set the clock manually
# 213 0.9665615578617778 what are the steps to set sleep timer for the tv
# 214 0.9997852982986982 how do i turn off the tv using off timer
# 215 0.9999999999999999 how do i select ambient light detection
# 216 0.9999999999999999 how do i select minimum backlight
# 217 0.9999999999999999 how do i update tvs software through a usb device
# 218 0.9999999999999999 how do i update tvs software automatically
# 219 0.06237828615518053 what is the use of smart security
# 220 0.9999999999999999 how do i scan tv for malicious code
# 221 0.9999604961681129 where can i view bixby guide
# 222 0.9997841818782067 how to create new account
# 223 0.9999604961681129 where can i find experience points xp
# 224 0.06237828615518053 what is the feature of bixby guide
# 225 0.9665615578617778 what all things must be required to use the bixby function
# 226 0.9665615578617778 what are the requirements for using bixby
# 227 0.9999760547866449 where to view tvs software version
# 228 0.9997841818782067 how to update tvs software through internet
# 229 0.9997852982986982 how to update the tv automatically
# 230 0.9997841818782067 how to turn remote management on and off
# 231 0.06237828615518053 what is remote support
# 232 0.9997852982986982 where can i find the call center phone number
# 233 0.9997852982986982 can i request service i am having problem with the tv
# 234 0.9999932912695934 how to connect to internet network
# 235 0.9997841818782067 how to establishing a wired internet connection
# 236 0.9997852982986982 can i check the internet connection status
# 237 0.9999932912695934 how to reset network
# 238 0.9997852982986982 can i turn on the tv with a mobile device
# 239 0.9997852982986982 how to configure the ipv6 connection settings
# 240 0.9997852982986982 how to check the internet connection set up over ipv6
# 241 0.9993063048340446 can i changing the name of the tv on a network
# 242 0.9997841818782067 my ip auto setting failed how to configure it
# 243 0.9997852982986982 i am unable to connect to the network how to resolve
# 244 0.9997852982986982 how to check the dns values in ip settings
# 245 0.9947279261542804 can you explain connecting with a component cable
# 246 0.9998201145011704 how to how to connect and use external speakers
# 247 0.9997852982986982 how can i connect my mobile device to the tv
# 248 0.9947279261542804 how to connect to the tv via the smartthings app
# 249 0.06237828615518053 what is access notification
# 250 0.9997852982986982 how to change the input signal
# 251 0.06237828615518053 what is connection guide
# 252 0.06237828615518053 what is universal remote
# 253 0.9665615578617778 what are the connection notes for hdmi
# 254 0.9947279261542804 can you explain the connection notes for computers
# 255 0.9665615578617778 what are the connection notes for mobile devices
# 256 0.9947279261542804 how to pair the tv with the samsung smart remote
# 257 0.9997852982986982 how to delete the notifications
# 258 0.9997852982986982 where can i select the services which i want to be notified
# 259 0.9999999999999999 where do i find accessibility functions
# 260 0.9999999999999999 how do i activate voice guide
# 261 0.9988367534372583 how do i enable audio for video description function
# 262 0.9999999999999999 how do i enable high contrast
# 263 0.7498378553650925 how do i change tv screen to grayscale mode
# 264 0.9997852982986982 how do i invert the screen colors
# 265 0.06237828615518053 what is the function of learn tv remote
# 266 0.9999999999999999 where do i find caption settings
# 267 0.9997852982986982 how to select the caption language
# 268 0.06237828615518053 what is the function of digital caption
# 269 0.9999999999999999 how do i enabledisable light effect
# 270 0.7498378553650925 how do i select usage or retail mode
# 271 0.9999999999999999 how do i do factory reset
# 272 0.9999604961681129 how can i use remote management option
# 273 0.9665615578617778 what does remote support offer
# 274 0.9980825675929894 how do you do remote support
# 275 0.9833821803872265 how do i get information about the tv
# 276 0.9999604961681129 how can i request for service
# 277 0.9999999999999999 where do i find signal information
# 278 0.9999999999999999 how do i smart hub connection test
# 279 0.9999999999999999 how do i reset smart hub
# 280 0.9999999999999999 how do i do reset
# 281 0.9997852982986982 how can i fix the flickering and dimming issues
# 282 0.9997852982986982 how do i fix the screen color issues
# 283 0.9999999999999999 how do i fix screen brightness issues
# 284 0.9999999999999999 how do i fix blurring issues on tv screen
# 285 0.9999604961681129 how can i fix unwanted powering off issue
# 286 0.9999999999999999 how do i fix powering on issue
# 287 0.06237828615518053 what do i do if the channel is not found
# 288 0.06237828615518053 what do i do if picture is distorted
# 289 0.9997852982986982 how do i fix the missingwrong color issue
# 290 0.9997852982986982 how do i fix the poor color issue
# 291 0.9993063048340446 how do i fix dotted line issue on the edge of tv screen
# 292 0.9999999999999999 how do i fix black and white issue
# 293 0.9999999999999999 how do i fix low volume issue
# 294 0.06237828615518053 what can i do if picture is good but there is no sound with it
# 295 0.9205817818752566 what can i do if i hear no sound
# 296 0.9205817818752566 how do i fix odd sound of speaker
# 297 0.9999999999999999 how do i fix weak or no signal issue
# 298 0.9999999999999999 i am not getting captions for digital channels how to fix this
# 299 0.9665615578617778 what can i do if i am getting distorted picture on tv
# 300 0.9999999999999999 how do i fix low quality picture issue
# 301 0.7498378553650925 mode not supported message appears on my computer how do i fix this
# 302 0.06237828615518053 i am able to see the video but no audio is there in my computer how can i fix this
# 303 0.06237828615518053 what can i do if tv is not connecting to the network
# 304 0.9665615578617778 what do i do if wireless network connection failed
# 305 0.06237828615518053 wireless network signal is too weak how can i fix this
# 306 0.06237828615518053 schedule recording is not working how can i fix this issue
# 307 0.06237828615518053 anynet is not working what should i do
# 308 0.9999999999999999 how do i start anynet
# 309 0.9999999999999999 how do i exit anynet
# 310 0.9999999999999999 how do i fix connectingdisconnecting to anynet device which appears on screen
# 311 0.9665615578617778 anynet device wont play what should i do
# 312 0.06237828615518053 connected device is not displaying how can i fix this
# 313 0.06237828615518053 tv audio is not being played through the receiver what should i do
# 314 0.9997852982986982 how can i change the language from app
# 315 0.9999999999999999 how do i reset settings
# 316 0.9999999999999999 how do i reset picture
# 317 0.9205817818752566 how do i reset sound settings
# 318 0.06237828615518053 there is a notification icon in the tv screen what is the use of it on tv screen
# 319 0.06237828615518053 i want to know about settings option in smart hub what is it
# 320 0.06237828615518053 i want to know about source option in the smart hub what is it
# 321 0.06237828615518053 there is an apps option in the smart hub how can i use that
# 322 0.06237828615518053 i dont know about universal guide what is it
# 323 0.7498378553650925 i dont know about ambient mode can you explain briefly
# 324 0.9996774705074848 my tv screen becomes darker why
# 325 0.9997841818782067 my tv screen automatically became black screen how
# 326 0.06237828615518053 i want to  enter in to ambient mode when the tv is turned off how can i do that
# 327 0.7498378553650925 i to change the ambient mode settings how can i do that
# 328 0.9833821803872265 i want  to get information about weather how can i do that
# 329 0.7498378553650925 i to set wallpaper of the ambient mode screen how can i do that
# 330 0.9833821803872265 i want  to adjust the screen brightness can you explian about that
# 331 0.9993063048340446 i dont like the color of my tv screen how can i change the color
# 332 0.9997852982986982 i want to change the auto brightness setting how can i do that
# 333 0.06237828615518053 what is ambient off timer how can i use it
# 334 0.7498378553650925 how do i change the background color of ambient mode
# 335 0.7498378553650925 can i select standard mode
# 336 0.7498378553650925 can i select movie mode
# 337 0.9999604961681129 can i configure backlight
# 338 0.9999604961681129 can i configure brightness
# 339 0.9999604961681129 can i configure sharpness
# 340 0.9999604961681129 can i configure color
# 341 0.9999604961681129 can i configure tint
# 342 0.9999604961681129 can i configure apply picture settings
# 343 0.9999604961681129 can i configure digital clean view
# 344 0.9999604961681129 can i configure local dimming
# 345 0.9999604961681129 can i configure contrast enhancer
# 346 0.7498378553650925 can i configure hdr mode
# 347 0.7498378553650925 can i configure film mode
# 348 0.9999604961681129 can i configure color tone
# 349 0.9999604961681129 can i configure gamma
# 350 0.7498378553650925 can i configure rgb only mode
# 351 0.9999604961681129 can i configure color space settings
# 352 0.9999604961681129 can i configure reset picture
# 353 0.7498378553650925 i want to change game mode settings how to do this
# 354 0.9999604961681129 can i configure game motion plus
# 355 0.9993063048340446 i want to change the size of the picture to 169 how to do
# 356 0.9993063048340446 can i change the size of the picture to 43
# 357 0.9947279261542804 can i fit the picture to the screen
# 358 0.9997852982986982 can i adjust the picture size or position
# 359 0.7498378553650925 can i select standard sound mode
# 360 0.7498378553650925 can i select optimized sound mode
# 361 0.7498378553650925 what are the steps to amplify sound mode
# 362 0.9205817818752566 can i balance the sound quality
# 363 0.9999604961681129 can i change equalizer
# 364 0.9999604961681129 can i change hdmi input audio format
# 365 0.9968432665441818 can i configure digital output audio format
# 366 0.9205817818752566 can i balance the sound quality
# 367 0.9999604961681129 can i configure audio delay
# 368 0.9999604961681129 can i change auto volume
# 369 0.9205817818752566 can i select sound feedback
# 370 0.9205817818752566 can i reset the sound
# 371 0.9947279261542804 can i connect to the bluetooth audio devices to the tv
# 372 0.9988367534372583 can i connect to the samsung wireless audio devices which has wifi enabled function
# 373 0.9947279261542804 can i set the current time on the tv
# 374 0.9665615578617778 what are the different cases do i need to reset the clock time
# 375 0.9997852982986982 can i set the clock automatically
# 376 0.9999604961681129 can i set time zone
# 377 0.9999604961681129 can i set daylight saving time dst
# 378 0.9997852982986982 can i change the current time on tv
# 379 0.9996012472825965 how do i set sleep timer for the tv
# 380 0.9997852982986982 can i turn off the tv using off timer
# 381 0.9999604961681129 can i prevent screen burn
# 382 0.9999604961681129 can i select ambient light detection
# 383 0.9999604961681129 can i select minimum backlight
# 384 0.9999604961681129 can i select auto power off
# 385 0.9999604961681129 can i update tvs software through a usb device
# 386 0.9999604961681129 can i update tvs software automatically
# 387 0.9999604961681129 how can i use smart security
# 388 0.9999604961681129 can i scan tv for malicious code
# 389 0.7498378553650925 where do i find sound mode option and how to use it
# 390 0.9205817818752566 where do i find sound output otion and how do i use this
# 391 0.9988367534372583 i need the caption function to be activated how to do that
# 392 0.06237828615518053 where do i find sleep timer function what is the use of it
# 393 0.9997852982986982 i want to know the current network how to check that
# 394 0.9997852982986982 can i select an external device connected to the tv
# 395 0.9947279261542804 where do i find the option to search the apps in smart hub services
# 396 0.9993063048340446 i want to use the feature of apps how can i do that
# 397 0.9999999999999999 where do i find bixby guide
# 398 0.9980825675929894 i need to create an acoount for my samsung tv how do i do that
# 399 0.9997852982986982 i need to change the current channel by saying channel names how can i do this
# 400 0.9988367534372583 how do i use the bixby function
# 401 0.9999999999999999 where do i find tvs software version
# 402 0.9665615578617778 what are the steps to update tvs software through internet
# 403 0.9665615578617778 what are the steps to update tvs software through usb device
# 404 0.9997852982986982 i want to update the tv automatically how can i do that
# 405 0.9999999999999999 how do i turn on or off remote management
# 406 0.9665615578617778 what does remote support mean
# 407 0.9980825675929894 i am facing problems in my tv how do i get remote support
# 408 0.9993063048340446 how do i find phone number of call center
# 409 0.9997852982986982 how do i request service for the tv
# 410 0.9665615578617778 what are the steps to connect to the internet network
# 411 0.9999999999999999 how do i establish a wired internet connection
# 412 0.9997852982986982 how do i check the internet connection status
# 413 0.9665615578617778 what are the steps to reset network
# 414 0.9997852982986982 how do i turn on the tv with a mobile device
# 415 0.9665615578617778 what are the steps to connect an ip control device to the tv
# 416 0.9997852982986982 can i configure the ipv6 connection settings
# 417 0.9997852982986982 can i check the internet connection set up over ipv6
# 418 0.9993063048340446 how do i change the name of the tv on a network
# 419 0.06237828615518053 i am getting error wireless router is not found how do i fix this
# 420 0.9999999999999999 how do i configure failed ip auto setting
# 421 0.9980825675929894 i am getting error not connected to network how do i fix this
# 422 0.9997852982986982 where do i find the dns values in ip settings
# 423 0.9999999999999999 how do i connect with a component cable
# 424 0.9665615578617778 what are the steps to connect with a composite cable
# 425 0.9999604961681129 can i connect and use external speakers
# 426 0.9665615578617778 what are the steps to connect my mobile device to the tv
# 427 0.9999999999999999 how do i do bidirectional mirroring
# 428 0.9993063048340446 how do i view a list of mobile devices registered to the tv
# 429 0.9665615578617778 what are the steps to change the input signal
# 430 0.9665615578617778 what does connection guide mean
# 431 0.9665615578617778 what are the recommended connection for hdmi
# 432 0.9665615578617778 how do i get better audio quality what are the connections guidelines for it
# 433 0.06237828615518053 what is the connection notes for computers
# 434 0.9999999999999999 where do i find connection notes for mobile devices
# 435 0.9947279261542804 how to pair the tv with the samsung smart remote
# 436 0.9999999999999999 where do i find accessibility shortcuts functions
# 437 0.9988367534372583 can i enable audio for video description function
# 438 0.9997852982986982 where do i find the to enable high contrast
# 439 0.7498378553650925 can i change tv screen to grayscale mode
# 440 0.9997852982986982 can i invert the screen colors
# 441 0.9997852982986982 can i increase the font size
# 442 0.06237828615518053 what is the features of learn tv remote
# 443 0.06237828615518053 what is the features of learn menu screen
# 444 0.9999999999999999 how do i find caption settings
# 445 0.9997852982986982 can i select the caption language
# 446 0.9999999999999999 where do i find digital caption option
# 447 0.9997852982986982 how do i listen to the tv through bluetooth devices
# 448 0.9997852982986982 can i change the menu language option
# 449 0.9999604961681129 i want to enabledisable light effect how can i do this
# 450 0.7498378553650925 can i select usage or retail mode
# 451 0.9999999999999999 where do i find factory reset option
# 452 0.9833821803872265 i want to know the information about the tv how can i find this
# 453 0.9999604961681129 can i request for service
# 454 0.9999604961681129 can i troubleshoot video issues
# 455 0.9205817818752566 can i troubleshoot sound issues
# 456 0.9997852982986982 how do i know the signal information
# 457 0.9999604961681129 can i do smart hub connection test
# 458 0.9999604961681129 can i do reset smart hub
# 459 0.9999999999999999 where do i find reset option
# 460 0.9997852982986982 can i fix the flickering and dimming issues
# 461 0.9997852982986982 can i fix the screen color issues
# 462 0.9999604961681129 can i fix screen brightness issues
# 463 0.9665615578617778 what are the steps to fix blurring issues on tv screen
# 464 0.9999999999999999 how do i fix unwanted powering off issue
# 465 0.9999604961681129 can i fix powering on issue
# 466 0.06237828615518053 i am getting channel is not found error how to fix this
# 467 0.06237828615518053 what can i do if picture is distorted
# 468 0.9997852982986982 can i fix the missingwrong color issue
# 469 0.9997852982986982 can i fix the poor color issue
# 470 0.9993063048340446 can i fix dotted line issue on the edge of tv screen
# 471 0.9999604961681129 can i fix black and white issue
# 472 0.9999604961681129 can i fix low volume issue
# 473 0.9205817818752566 what to do if i hear no sound
# 474 0.9205817818752566 can i fix odd sound of speaker
# 475 0.9999604961681129 can i fix weak or no signal issue
# 476 0.06237828615518053 my tv is not receiving channels what should i do
# 477 0.06237828615518053 is there any way i can get captions for digital channels
# 478 0.9999999999999999 i am getting distorted picture on tv how to fix this issue
# 479 0.06237828615518053 tv is not connecting to the network what should i do
# 480 0.9999604961681129 wireless network connection failed how can i fix this
# 481 0.06237828615518053 what can i do when wireless network signal is too weak
# 482 0.06237828615518053 what can i do if schedule recording is not working
# 483 0.06237828615518053 what is source and how to serch data for channels
# 484 0.9997852982986982 how to install app and how to use universal guide
# 485 0.9993063048340446 why my screen getting darker and also sometimes in state of black screen
# 486 0.06237828615518053 what is decor and how to set wallpaper of the ambient mode screen
# 487 0.9993063048340446 how to adjust the brightness and color of the screen
# 488 0.9665615578617778 what are the features of auto brightness and ambient off timer
# 489 0.06237828615518053 how to sign in to samsung account and what is bixby guide
# 490 0.06237828615518053 how to change the voice style of bixby and what is the use of user information
# 491 0.9999604961681129 can i update software through internet and through usb device
# 492 0.06237828615518053 what is remote support and how it works
# 493 0.9997852982986982 how to establish wireless internet connection and how to check the internet connection
# 494 0.9997852982986982 how to configure failed ip auto setting and i am unable to connect to the network how to fix this
# 495 0.7498378553650925 what are dynamic and standard mode
# 496 0.7498378553650925 what are natural and movie mode
# 497 0.9205817818752566 where can i get digital output audio format and sound mirroring
# 498 0.9947279261542804 can i remove the registered channels and add back the removed channels
# 499 0.9997841818782067 how to configure backlight and brightness
# 500 0.9997841818782067 how to configure contrast and sharpness
# 501 0.9999999999999999 how do i configure tint and apply picture settings
# 502 0.9999999999999999 how do i configure white balance and gamma
# 503 0.7498378553650925 how do i configure rgb only mode and color space settings
# 504 0.9999516294168106 where to select time zone and how to adjusts for daylight saving time
# 505 0.9947279261542804 how to change the current time and set the clock manually
# 506 0.9996012472825965 how to use the sleep timer and turn off the tv using the off timer
# 507 0.06237828615518053 what is ambient light detection and minimum backlight
# 508 0.06237828615518053 what is power saving mode and motion lighting
# 509 0.06237828615518053 what is default  cc1  cc4 text1  text4 and default  service1  service6  cc1  cc4  text1  text4
# 510 0.06237828615518053 how can i connect my samsungsmartremote to tv automatically and if it is not connected what will i do
# 511 0.06237828615518053 how to select air or cable as the dtv mode and what is the use of tv plus
# 512 0.9988367534372583 how do i record using time timeshift function and how to go to the live tv
# 513 0.9993063048340446 how do i stop recording  stop timeshift and how do i get the information of recorded program
# 514 0.9999604961681129 how to do slow forward or slow rewind and how can i jump forward  jump backward
# 515 0.9665615578617778 explain the steps how to do schedule recording while watching a program and explain the steps how to do schedule recording while watching a program
# 516 0.06237828615518053 please instruct how to record any program and is there any way to stop the recording
# 517 0.9947279261542804 please provide some instructions on how to schedule program and also can you please explain how to schedule recording
# 518 0.9665615578617778 please explain the procedure how to edit recording time and explain the procedure for cancelling scheduled viewing  scheduled recording
# 519 0.9968432665441818 how can i select channel filter option and how can i change antenna type
# 520 0.9205817818752566 how do i troubleshoot video issues and how do i troubleshoot sound issues
# 521 0.9980825675929894 where do i find signal information and how do i smart hub connection test
# 522 0.9980825675929894 how do i reset smart hub and how do i do reset
# 523 0.9980825675929894 how do i use voice guide and how do i select high contrast
# 524 0.9909044601811138 where do i find the option of learn tv remote and where do i find the option of learn menu screen
# 525 0.9980825675929894 how do i turn on voice guide using bixby and how do i turn on video description using bixby
# 526 0.06237828615518053 how do i start recording and what is timeshift
# 527 0.9833821803872265 how do i stop recording and where do i find information about my program
# 528 0.9999604961681129 can i enlarge my tv screen
# 529 0.9988367534372583 can i activate the caption function
# 530 0.06237828615518053 is it possible to turn tv in ambient mode
# 531 0.9997852982986982 can i test the smart hub connections
# 532 0.9999604961681129 can i create and manage my samsung account
# 533 0.9999604961681129 can i create a samsung account using a paypal account
# 534 0.9997852982986982 can i change the information to a samsung account
# 535 0.9999604961681129 can i view privacy policy
# 536 0.9999604961681129 can i check app details
# 537 0.9999604961681129 can i update apps automatically
# 538 0.9999604961681129 can i turn off notifications
# 539 0.9999604961681129 can i turn on voice guide using bixby
# 540 0.9999604961681129 can i turn on high contrast using bixby
# 541 0.9999604961681129 can i cancel scheduled viewing  cancel scheduled recording
# 542 0.06237828615518053 is my samsung smart remote automatically pairs to the tv
# 543 0.06237828615518053 is it possible to install different apps using smart hub in my tv
# 544 0.7498378553650925 can i change the content and settings for ambient mode
# 545 0.9999604961681129 can i connect various external devices to my tv
#
#
# Question:  signal information under self diagnosis isnt activated how do i activate that
#
#
# Retrieved:  i need to lock app. how to do this?
# Answer:  select settings on apps. you can manage installed apps. select an app to lock or unlock. select lock/unlock. the selected app is locked or unlocked. to lock or unlock an app, enter the pin. the default pin is '0000.' you can set the pin in settings general system manager change pin.

# %% [markdown]
# # Word2Vec Embeddings

# %% [markdown]
# **Skipgram model**

# %%
from gensim.models import Word2Vec 
import gensim.downloader as api

w2v_model=None
try:
    w2v_model = gensim.models.KeyedVectors.load("../data/w2vecmodel.mod")
    print("Loaded w2v model")
except:            
    w2v_model = api.load('word2vec-google-news-300')
    w2v_model.save("../data/w2vecmodel.mod")
    print("Saved glove model")

w2vec_embedding_size=len(w2v_model['computer'])
# Out:
# Loaded w2v model

# %% [markdown]
# **Getting Phrase Embeddings from Word Embeddings**

# %%
def getWordVec(word,model):
        samp=model['computer']
        vec=[0]*len(samp)
        try:
                vec=model[word]
        except:
                vec=[0]*len(samp)
        return (vec)


def getPhraseEmbedding(phrase,embeddingmodel):
                       
        samp=getWordVec('computer', embeddingmodel)
        vec=numpy.array([0]*len(samp))
        den=0
        for word in phrase.split():
            den=den+1
            vec=vec+numpy.array(getWordVec(word,embeddingmodel))
        return vec.reshape(1, -1)

# %%
#With w2Vec

sent_embeddings=[]
for sent in cleaned_sentences:
    sent_embeddings.append(getPhraseEmbedding(sent,w2v_model))

question_embedding=getPhraseEmbedding(question,w2v_model)

retrieveAndPrintAnswer(question_embedding,sent_embeddings,df,cleaned_sentences)
# Out:
# 0 0.3917313045094571 sound mode
# 1 0.3925412569781399 explain sound output
# 2 0.4112559041323438 function sleep timer
# 3 0.3360633031857873 view current network
# 4 0.531323061182427 select external device connected tv
# 5 0.3651834009951936 search apps smart hub services
# 6 0.3623130384427682 use feature apps
# 7 0.4176118181970096 turn tv ambient mode
# 8 0.31533836105953894 item home screen
# 9 0.5101820539192932 turn autorun smart hub function
# 10 0.4420087058408628 launch app automatically
# 11 0.38104795592075474 test smart hub connections
# 12 0.40335298329957014 reset smart hub
# 13 0.4170619784798318 create manage samsung account
# 14 0.3343663782196549 create new account
# 15 0.34221912531764354 create samsung account facebook account
# 16 0.32744196850905294 create samsung account paypal account
# 17 0.5213624832295437 change information samsung account
# 18 0.4383281337794791 configure sync internet settings
# 19 0.39535950905715017 delete samsung account
# 20 0.4040719696892737 sign samsung account
# 21 0.303636925453453 view privacy policy
# 22 0.40072840641899204 install app
# 23 0.3834394644250693 delete app
# 24 0.3656523061506754 add apps home screen
# 25 0.47816420292378026 need lock app
# 26 0.325020445534581 app location
# 27 0.3469137391143745 reinstall apps
# 28 0.454153397392648 update apps automatically
# 29 0.320019246365198 rate apps
# 30 0.433978593747395 use universal guide
# 31 0.0 smartthings
# 32 0.40256598622209727 select location list smart
# 33 0.3343663782196549 create new account smartthings
# 34 0.45022276153744994 items turn notifications
# 35 0.38344309245101355 create custom mode
# 36 0.4827026611891458 view list connected smart devices
# 37 0.19897776476622994 launch emanual
# 38 0.33828389158867556 uses buttons emanual
# 39 0.25832850777530075 surf internet tv
# 40 0.33516133801912606 tv getting hot
# 41 0.31957140917009774 getting display picture
# 42 0.47765532478025724 mode supported appears screen fix
# 43 0.40609261498939686 captions tv grayed fix
# 44 0.298923037843148 tv smells plastic
# 45 0.19533460623771337 stand wobbly crooked
# 46 0.5079292102902184 broadcasting function deactivated
# 47 0.23846014839848761 pip available
# 48 0.41163433477230243 settings lost everytime tv turned
# 49 0.38223929517516597 pop tvs internal banner ad appears screen change
# 50 0.4415904923699256 software update internet failed fix
# 51 0.37789542806741977 rotate samsung tv screen
# 52 0.4512465014947547 happen press color buttons
# 53 0.42451058038959183 things playpause button
# 54 0.43698268389650297 use voice guide
# 55 0.28471433392055934 enlarge screen
# 56 0.5015452729084431 option learn tv remote
# 57 0.41207066786308505 option learn menu screen
# 58 0.2605196089005102 open accessibility shortcuts menu
# 59 0.39650734127427434 turn voice guide
# 60 0.4122910301623823 turn video description
# 61 0.42477573581374284 access main accessibility menu change voice guide settings
# 62 0.39650734127427434 turn voice guide bixby
# 63 0.4122910301623823 turn video description bixby
# 64 0.28718602653458375 turn high contrast bixby
# 65 0.39872193884961626 turn tv voice
# 66 0.3462640088495677 change channel
# 67 0.43590361525010357 view program information
# 68 0.1728099663546416 schedule program
# 69 0.2901591463453356 edit recording time
# 70 0.3241570669461032 stop recording
# 71 0.2749571726981017 cancel scheduled viewing cancel scheduled recording
# 72 0.33940928751821153 details program
# 73 0.22279477066562303 list favorite channels
# 74 0.38471491018515525 guide screen option
# 75 0.4455024051696517 program info screen
# 76 0.3434390123254529 cancel scheduled view guide
# 77 0.35495587973101583 check list channels
# 78 0.31380902362207724 check list favorite channels
# 79 0.30102151155370177 register channels favorite
# 80 0.2780769305358024 add channels favorite list
# 81 0.33570901858931923 delete channels favorite list
# 82 0.31818421312333045 view select channels favorite lists
# 83 0.3302378105302617 start recording
# 84 0.19050786693905356 timeshift
# 85 0.3241570669461032 stop recording
# 86 0.4225341455623237 information program
# 87 0.29193642314484886 set length recording time
# 88 0.19323359767997825 recorded program
# 89 0.38347624724657325 steps delete recorded program
# 90 0.27093731863265846 open channel list
# 91 0.21793219440329253 schedule manager recordings
# 92 0.22280279000630165 view program watched recently
# 93 0.4385992565547332 delete notification
# 94 0.45327996206604365 select services want notified
# 95 0.44237092462062233 change picture mode
# 96 0.4911977934874283 change sound mode
# 97 0.39014668356002974 change sound output
# 98 0.4634422862345546 check current network internet status
# 99 0.33889044087222614 change source
# 100 0.4506869575691104 different types things ambient mode
# 101 0.0 emanual
# 102 0.6295434156286573 activate bixby
# 103 0.3575578435776298 delete recorded content
# 104 0.19827126869917264 precautions bixby
# 105 0.32521084464067224 instruct record program
# 106 0.3663377902359797 provide instructions schedule program
# 107 0.32897527230357276 explain schedule recording
# 108 0.4205040878225883 explain procedure edit recording time
# 109 0.40093101905065937 way stop recording
# 110 0.4225341455623237 program information
# 111 0.38853892374293986 select channel filter option
# 112 0.48226595706431197 change antenna type
# 113 0.33142467655653624 check schedule manager option
# 114 0.3767186169777434 instant recording guide screen
# 115 0.43526889421466197 explain steps schedule recording guide screen
# 116 0.39091559392770603 explain steps schedule recording watching program
# 117 0.39091559392770603 explain steps schedule recording watching program
# 118 0.3190491765010039 schedule recording date time entered
# 119 0.3471430134617409 manage recording list
# 120 0.3381024522462238 delete schedule recordings
# 121 0.2281979509525412 recording list
# 122 0.3476303101838464 start early recording
# 123 0.30946917198110174 continue recording program ended
# 124 0.2586198256959084 edit scheduled viewing
# 125 0.29985446210257327 set scheduled viewing time
# 126 0.23737986994392876 cancel sheduled viewing
# 127 0.2552804587498749 check scheduled viewings
# 128 0.3926480253854318 record time timeshift function
# 129 0.2773328876503436 live tv
# 130 0.3624183675388079 stop recording stop timeshift
# 131 0.3145339618541617 slow forward slow rewind
# 132 0.19249315578029344 jump forward jump backward
# 133 0.3412348935989511 fast forward rewind
# 134 0.350434339777552 lock current channel
# 135 0.42277820675588274 view channels serached auto program function
# 136 0.42483238122855305 select air cable dtv mode
# 137 0.42231601127665774 use tv plus
# 138 0.36841858185462817 add removed channels
# 139 0.1874983662245124 rename channel
# 140 0.3289292156802479 watch blocked restricted channels
# 141 0.3108827023728382 steps register channels favorites
# 142 0.30898339987087914 select view channels favorite list
# 143 0.1900121304406026 edit favorites list
# 144 0.2557969247420685 add channels favorites list
# 145 0.2968375601421706 remove channels favorites list
# 146 0.2167689550119173 rearrange favorites list
# 147 0.4518164946063053 change broadcasting signal
# 148 0.4242703719173412 scan available channels
# 149 0.4359873530120577 hpw configure advanced broadcasting audio settings
# 150 0.31163204559343544 multitrack sound option
# 151 0.35331833401526247 connect samsungsmartremote tv
# 152 0.48960605350320496 use notification icon tv screen
# 153 0.3840905650932228 settings option smart hub
# 154 0.33089646886961005 source option smart hub
# 155 0.43121867037781114 use search option tne smart hub
# 156 0.4310819630114938 use apps option smart hub
# 157 0.4240015706139123 turn ambient mode tv screen
# 158 0.32360342134803205 universal guide
# 159 0.41689160491276805 explain ambient mode
# 160 0.29883476160429556 tv screen black screen
# 161 0.4156304597924986 enter ambient mode tv turned
# 162 0.41060386086421563 change ambient mode settings
# 163 0.26920508252694786 select beautiful screens
# 164 0.3998876555652034 information weather
# 165 0.3580306588750958 set wallpaper ambient mode screen
# 166 0.34425674739341355 adjust screen brightness
# 167 0.36288181679781917 change auto brightness setting
# 168 0.23741614586755208 ambient timer
# 169 0.4168016558836737 change background color ambient mode
# 170 0.3882164788451064 select dynamic mode
# 171 0.36752645498454406 select standard mode
# 172 0.38709213517296454 select natural mode
# 173 0.39189254945459934 select movie mode
# 174 0.3809831031481172 configure backlight
# 175 0.34004975220607236 configure brightness
# 176 0.3361585749795015 configure contrast
# 177 0.36524800319895423 configure sharpness
# 178 0.3945010765202903 configure color
# 179 0.3578180182603022 configure tint
# 180 0.4799629828029777 configure apply picture settings
# 181 0.4271732244465649 configure digital clean view
# 182 0.44621812851981224 configure auto motion plus settings
# 183 0.42456180699618695 configure local dimming
# 184 0.381409691741757 configure contrast enhancer
# 185 0.42341898295452773 configure hdr mode
# 186 0.42026223714820726 configure film mode
# 187 0.3917002241672042 configure color tone
# 188 0.3881595341028301 configure gamma
# 189 0.43766096562501833 configure rgb mode
# 190 0.39743375069561276 configure color space settings
# 191 0.46682524151586946 configure game motion plus
# 192 0.4333007781816374 use hdmi uhd color
# 193 0.46126499731422926 adjust hdmi black level
# 194 0.3327663918440609 change size picture 169
# 195 0.35854866215344544 change size picture custom
# 196 0.3327663918440609 change size picture 43
# 197 0.3187866657958855 fit picture screen
# 198 0.4265784593391708 select standard sound mode
# 199 0.44716674852733823 select optimized sound mode
# 200 0.4310392854592922 amplify sound mode
# 201 0.2870186460720612 balance sound quality
# 202 0.32600830578613615 change auto volume
# 203 0.42426761146031267 select sound feedback
# 204 0.3602608037230314 select speaker sound output
# 205 0.45100661216979465 connect bluetooth audio devices tv
# 206 0.40239370455971424 set current time tv
# 207 0.49276616398609085 cases need reset clock time
# 208 0.4210223497816959 set clock automatically
# 209 0.2901322436404116 set time zone
# 210 0.3766904926419222 set daylight saving time dst
# 211 0.4552070640330048 change current time tv
# 212 0.35586194580681013 set clock manually
# 213 0.4276814234536032 steps set sleep timer tv
# 214 0.37726342392611223 turn tv timer
# 215 0.45877528466468276 select ambient light detection
# 216 0.3743957796662568 select minimum backlight
# 217 0.3788507904543991 update tvs software usb device
# 218 0.4344736552933364 update tvs software automatically
# 219 0.4388847575431153 use smart security
# 220 0.42917157196004835 scan tv malicious code
# 221 0.30057522005060017 view bixby guide
# 222 0.3343663782196549 create new account
# 223 0.29826263080156823 experience points xp
# 224 0.259785878053782 feature bixby guide
# 225 0.598253325061197 things required use bixby function
# 226 0.20256775103064895 requirements bixby
# 227 0.2931802586035454 view tvs software version
# 228 0.35778853894539214 update tvs software internet
# 229 0.49105036243550826 update tv automatically
# 230 0.420169097506809 turn remote management
# 231 0.38939403233464454 remote support
# 232 0.3136863574544 center phone number
# 233 0.4735895249730153 request service having problem tv
# 234 0.33564266762988476 connect internet network
# 235 0.4055051283594137 establishing wired internet connection
# 236 0.4749508622329908 check internet connection status
# 237 0.40275147507569475 reset network
# 238 0.4600527211960379 turn tv mobile device
# 239 0.42020712228798046 configure ipv6 connection settings
# 240 0.4412244602996321 check internet connection set ipv6
# 241 0.36016113066256067 changing tv network
# 242 0.42846683439709227 ip auto setting failed configure
# 243 0.40260795733081034 unable connect network resolve
# 244 0.39611717389502366 check dns values ip settings
# 245 0.42765298404499735 explain connecting component cable
# 246 0.4240937554241325 connect use external speakers
# 247 0.4387558541702426 connect mobile device tv
# 248 0.4113509872250647 connect tv smartthings app
# 249 0.4023230365232446 access notification
# 250 0.498115133795665 change input signal
# 251 0.3482508547848786 connection guide
# 252 0.3266453780443592 universal remote
# 253 0.35496546807581403 connection notes hdmi
# 254 0.39883459027233303 explain connection notes computers
# 255 0.36180487766791647 connection notes mobile devices
# 256 0.41952820501094823 pair tv samsung smart remote
# 257 0.4214085990051076 delete notifications
# 258 0.45327996206604365 select services want notified
# 259 0.30932083690827294 accessibility functions
# 260 0.594509279802782 activate voice guide
# 261 0.47555401840008754 enable audio video description function
# 262 0.29533476197819836 enable high contrast
# 263 0.4242303006216932 change tv screen grayscale mode
# 264 0.30016841873564537 invert screen colors
# 265 0.5440272682676947 function learn tv remote
# 266 0.27123752834843207 caption settings
# 267 0.29924348928499517 select caption language
# 268 0.3621952452123451 function digital caption
# 269 0.3693369075916423 enabledisable light effect
# 270 0.4064656132363648 select usage retail mode
# 271 0.2802111258204939 factory reset
# 272 0.4612418422609828 use remote management option
# 273 0.3974071155083586 remote support offer
# 274 0.38939403233464454 remote support
# 275 0.43883645995660703 information tv
# 276 0.3305414799192414 request service
# 277 0.5600846255495161 signal information
# 278 0.41975940539010376 smart hub connection test
# 279 0.40335298329957014 reset smart hub
# 280 0.34525137756459157 reset
# 281 0.3658512861264085 fix flickering dimming issues
# 282 0.38896484718464125 fix screen color issues
# 283 0.3711260757531712 fix screen brightness issues
# 284 0.3794299370767028 fix blurring issues tv screen
# 285 0.35409261559361727 fix unwanted powering issue
# 286 0.3371237998705755 fix powering issue
# 287 0.17526652835731177 channel
# 288 0.22134565444507104 picture distorted
# 289 0.3546142673273839 fix missingwrong color issue
# 290 0.3681773954407397 fix poor color issue
# 291 0.37425544054505067 fix dotted line issue edge tv screen
# 292 0.3113797293731168 fix black white issue
# 293 0.3375765410556681 fix low volume issue
# 294 0.3702857849763639 picture good sound
# 295 0.3486167076320997 hear sound
# 296 0.3656552085064101 fix odd sound speaker
# 297 0.4552994936036495 fix weak signal issue
# 298 0.41399292740672056 getting captions digital channels fix
# 299 0.34877922401019124 getting distorted picture tv
# 300 0.33925575803660474 fix low quality picture issue
# 301 0.51654400471616 mode supported message appears fix
# 302 0.4584633231758373 able video audio fix
# 303 0.32545448521815684 tv connecting network
# 304 0.38435319914290395 wireless network connection failed
# 305 0.46907452772422503 wireless network signal weak fix
# 306 0.36186822721507955 schedule recording working fix issue
# 307 0.22456064062079392 anynet working
# 308 0.31871513236759086 start anynet
# 309 0.2074288588180411 exit anynet
# 310 0.4644898035090051 fix connectingdisconnecting anynet device appears screen
# 311 0.5024525798666096 anynet device wont play
# 312 0.5041144076370133 connected device displaying fix
# 313 0.3426116753291838 tv audio played receiver
# 314 0.4096910092774719 change language app
# 315 0.38528871818489885 reset settings
# 316 0.3825560764414184 reset picture
# 317 0.4428691167594882 reset sound settings
# 318 0.4351099049987692 notification icon tv screen use tv screen
# 319 0.5071126792464706 want know settings option smart hub
# 320 0.46690432161016765 want know source option smart hub
# 321 0.4310819630114938 apps option smart hub use
# 322 0.5111850011691979 dont know universal guide
# 323 0.5395008940454219 dont know ambient mode explain briefly
# 324 0.2975932329788473 tv screen darker
# 325 0.3900161967577475 tv screen automatically black screen
# 326 0.46757173437973193 want enter ambient mode tv turned
# 327 0.41060386086421563 change ambient mode settings
# 328 0.49304804562574767 want information weather
# 329 0.3580306588750958 set wallpaper ambient mode screen
# 330 0.41728314441014536 want adjust screen brightness explian
# 331 0.440599892930153 dont like color tv screen change color
# 332 0.43290170808414824 want change auto brightness setting
# 333 0.359397599777769 ambient timer use
# 334 0.4168016558836737 change background color ambient mode
# 335 0.36752645498454406 select standard mode
# 336 0.39189254945459934 select movie mode
# 337 0.3809831031481172 configure backlight
# 338 0.34004975220607236 configure brightness
# 339 0.36524800319895423 configure sharpness
# 340 0.3945010765202903 configure color
# 341 0.3578180182603022 configure tint
# 342 0.4799629828029777 configure apply picture settings
# 343 0.4271732244465649 configure digital clean view
# 344 0.42456180699618695 configure local dimming
# 345 0.381409691741757 configure contrast enhancer
# 346 0.42341898295452773 configure hdr mode
# 347 0.42026223714820726 configure film mode
# 348 0.3917002241672042 configure color tone
# 349 0.3881595341028301 configure gamma
# 350 0.43766096562501833 configure rgb mode
# 351 0.39743375069561276 configure color space settings
# 352 0.47066076110159744 configure reset picture
# 353 0.5096214010757429 want change game mode settings
# 354 0.46682524151586946 configure game motion plus
# 355 0.4117904617997749 want change size picture 169
# 356 0.3327663918440609 change size picture 43
# 357 0.3187866657958855 fit picture screen
# 358 0.3435632374413428 adjust picture size position
# 359 0.4265784593391708 select standard sound mode
# 360 0.44716674852733823 select optimized sound mode
# 361 0.4521874736643494 steps amplify sound mode
# 362 0.2870186460720612 balance sound quality
# 363 0.2957057833563065 change equalizer
# 364 0.38887711204052855 change hdmi input audio format
# 365 0.33416586335123133 configure digital output audio format
# 366 0.2870186460720612 balance sound quality
# 367 0.4107219014509269 configure audio delay
# 368 0.32600830578613615 change auto volume
# 369 0.42426761146031267 select sound feedback
# 370 0.43261932676680326 reset sound
# 371 0.45100661216979465 connect bluetooth audio devices tv
# 372 0.47729606814128694 connect samsung wireless audio devices wifi enabled function
# 373 0.40239370455971424 set current time tv
# 374 0.5119477676084856 different cases need reset clock time
# 375 0.4210223497816959 set clock automatically
# 376 0.2901322436404116 set time zone
# 377 0.3766904926419222 set daylight saving time dst
# 378 0.4552070640330048 change current time tv
# 379 0.39070736448440246 set sleep timer tv
# 380 0.37726342392611223 turn tv timer
# 381 0.38692348515544467 prevent screen burn
# 382 0.45877528466468276 select ambient light detection
# 383 0.3743957796662568 select minimum backlight
# 384 0.35773993306074175 select auto power
# 385 0.3788507904543991 update tvs software usb device
# 386 0.4344736552933364 update tvs software automatically
# 387 0.4388847575431153 use smart security
# 388 0.42917157196004835 scan tv malicious code
# 389 0.48634712008151076 sound mode option use
# 390 0.3796616201557474 sound output otion use
# 391 0.6504451182787877 need caption function activated
# 392 0.48308628540121173 sleep timer function use
# 393 0.5289884582841922 want know current network check
# 394 0.531323061182427 select external device connected tv
# 395 0.40055200524848517 option search apps smart hub services
# 396 0.4347450458653134 want use feature apps
# 397 0.24223709972214014 bixby guide
# 398 0.44295726270098845 need create acoount samsung tv
# 399 0.4531029174138571 need change current channel saying channel names
# 400 0.48544765956206054 use bixby function
# 401 0.2447310425772645 tvs software version
# 402 0.39742758022178204 steps update tvs software internet
# 403 0.4148916460887093 steps update tvs software usb device
# 404 0.5401105864444309 want update tv automatically
# 405 0.420169097506809 turn remote management
# 406 0.4787887160807119 remote support mean
# 407 0.44016636621119204 facing problems tv remote support
# 408 0.3136863574544 phone number center
# 409 0.39915899956783973 request service tv
# 410 0.3883976222719571 steps connect internet network
# 411 0.43019642618083725 establish wired internet connection
# 412 0.4749508622329908 check internet connection status
# 413 0.436970046323834 steps reset network
# 414 0.4600527211960379 turn tv mobile device
# 415 0.5323497940427713 steps connect ip control device tv
# 416 0.42020712228798046 configure ipv6 connection settings
# 417 0.4412244602996321 check internet connection set ipv6
# 418 0.40998389542360186 change tv network
# 419 0.40447589735959855 getting error wireless router fix
# 420 0.42846683439709227 configure failed ip auto setting
# 421 0.4353549461096681 getting error connected network fix
# 422 0.33564970331579114 dns values ip settings
# 423 0.3697687605024496 connect component cable
# 424 0.35792761272802764 steps connect composite cable
# 425 0.4240937554241325 connect use external speakers
# 426 0.4812038132057209 steps connect mobile device tv
# 427 0.27305617729611925 bidirectional mirroring
# 428 0.4289819855254158 view list mobile devices registered tv
# 429 0.5041056466493334 steps change input signal
# 430 0.45154405801640596 connection guide mean
# 431 0.3719698963199336 recommended connection hdmi
# 432 0.41525024509941416 better audio quality connections guidelines
# 433 0.30665746968867635 connection notes computers
# 434 0.36180487766791647 connection notes mobile devices
# 435 0.41952820501094823 pair tv samsung smart remote
# 436 0.32507289368366843 accessibility shortcuts functions
# 437 0.47555401840008754 enable audio video description function
# 438 0.29533476197819836 enable high contrast
# 439 0.4242303006216932 change tv screen grayscale mode
# 440 0.30016841873564537 invert screen colors
# 441 0.23914739691349457 increase font size
# 442 0.4462596564856005 features learn tv remote
# 443 0.358993655336598 features learn menu screen
# 444 0.27123752834843207 caption settings
# 445 0.29924348928499517 select caption language
# 446 0.31154902848734656 digital caption option
# 447 0.46523305795285286 listen tv bluetooth devices
# 448 0.3780618384185987 change menu language option
# 449 0.4848784649802407 want enabledisable light effect
# 450 0.4064656132363648 select usage retail mode
# 451 0.34991268811559256 factory reset option
# 452 0.55419330257589 want know information tv
# 453 0.3305414799192414 request service
# 454 0.3545580593096945 troubleshoot video issues
# 455 0.3821055162085932 troubleshoot sound issues
# 456 0.6468727401321342 know signal information
# 457 0.41975940539010376 smart hub connection test
# 458 0.40335298329957014 reset smart hub
# 459 0.4005973945257471 reset option
# 460 0.3658512861264085 fix flickering dimming issues
# 461 0.38896484718464125 fix screen color issues
# 462 0.3711260757531712 fix screen brightness issues
# 463 0.40378673091133943 steps fix blurring issues tv screen
# 464 0.35409261559361727 fix unwanted powering issue
# 465 0.3371237998705755 fix powering issue
# 466 0.365865609773843 getting channel error fix
# 467 0.22134565444507104 picture distorted
# 468 0.3546142673273839 fix missingwrong color issue
# 469 0.3681773954407397 fix poor color issue
# 470 0.37425544054505067 fix dotted line issue edge tv screen
# 471 0.3113797293731168 fix black white issue
# 472 0.3375765410556681 fix low volume issue
# 473 0.3486167076320997 hear sound
# 474 0.3656552085064101 fix odd sound speaker
# 475 0.4552994936036495 fix weak signal issue
# 476 0.3205805697080376 tv receiving channels
# 477 0.3419458684269567 way captions digital channels
# 478 0.4096373546388024 getting distorted picture tv fix issue
# 479 0.32545448521815684 tv connecting network
# 480 0.4339431620602112 wireless network connection failed fix
# 481 0.4248415241140915 wireless network signal weak
# 482 0.25544251683158864 schedule recording working
# 483 0.36067208396542594 source serch data channels
# 484 0.5053219111704784 install app use universal guide
# 485 0.335005075979774 screen getting darker state black screen
# 486 0.31115782153058363 decor set wallpaper ambient mode screen
# 487 0.34877695666324277 adjust brightness color screen
# 488 0.3024143821052786 features auto brightness ambient timer
# 489 0.4466495445301418 sign samsung account bixby guide
# 490 0.5511360902262188 change voice style bixby use user information
# 491 0.4082525810123617 update software internet usb device
# 492 0.43303946492408857 remote support works
# 493 0.4261722243289835 establish wireless internet connection check internet connection
# 494 0.5047864750828498 configure failed ip auto setting unable connect network fix
# 495 0.3480702072991519 dynamic standard mode
# 496 0.3616744593560788 natural movie mode
# 497 0.30406586698195726 digital output audio format sound mirroring
# 498 0.3906833724672708 remove registered channels add removed channels
# 499 0.3417324968619121 configure backlight brightness
# 500 0.3483380499226061 configure contrast sharpness
# 501 0.4571343081120395 configure tint apply picture settings
# 502 0.4296732567867723 configure white balance gamma
# 503 0.43563976309357305 configure rgb mode color space settings
# 504 0.4019992565440043 select time zone adjusts daylight saving time
# 505 0.46795920010562975 change current time set clock manually
# 506 0.44106369075240065 use sleep timer turn tv timer
# 507 0.43166573379309947 ambient light detection minimum backlight
# 508 0.4452530920311492 power saving mode motion lighting
# 509 0.2351012086030003 default cc1 cc4 text1 text4 default service1 service6 cc1 cc4 text1 text4
# 510 0.4947492417286856 connect samsungsmartremote tv automatically connected
# 511 0.49021836969371807 select air cable dtv mode use tv plus
# 512 0.4122870226545587 record time timeshift function live tv
# 513 0.4524304048585913 stop recording stop timeshift information recorded program
# 514 0.29228393249395906 slow forward slow rewind jump forward jump backward
# 515 0.39091559392770603 explain steps schedule recording watching program explain steps schedule recording watching program
# 516 0.4421776403430279 instruct record program way stop recording
# 517 0.39509108688726813 provide instructions schedule program explain schedule recording
# 518 0.42818308437090047 explain procedure edit recording time explain procedure cancelling scheduled viewing scheduled recording
# 519 0.5148933056172749 select channel filter option change antenna type
# 520 0.3830899098796488 troubleshoot video issues troubleshoot sound issues
# 521 0.5830665080362691 signal information smart hub connection test
# 522 0.42193519047511907 reset smart hub reset
# 523 0.4427921327394833 use voice guide select high contrast
# 524 0.504666814743519 option learn tv remote option learn menu screen
# 525 0.46966910030079556 turn voice guide bixby turn video description bixby
# 526 0.3351860811842987 start recording timeshift
# 527 0.4987938185124159 stop recording information program
# 528 0.33163345818174417 enlarge tv screen
# 529 0.5812265207716385 activate caption function
# 530 0.4723745564321421 possible turn tv ambient mode
# 531 0.38104795592075474 test smart hub connections
# 532 0.4170619784798318 create manage samsung account
# 533 0.32744196850905294 create samsung account paypal account
# 534 0.5213624832295437 change information samsung account
# 535 0.303636925453453 view privacy policy
# 536 0.4280894764347845 check app details
# 537 0.454153397392648 update apps automatically
# 538 0.4615070743319823 turn notifications
# 539 0.39650734127427434 turn voice guide bixby
# 540 0.28718602653458375 turn high contrast bixby
# 541 0.2749571726981017 cancel scheduled viewing cancel scheduled recording
# 542 0.49421507274174437 samsung smart remote automatically pairs tv
# 543 0.5200020783322717 possible install different apps smart hub tv
# 544 0.4458471249478277 change content settings ambient mode
# 545 0.46648734765699534 connect external devices tv
#
#
# Question:  signal information under self diagnosis isnt activated how do i activate that
#
#
# Retrieved:  i need the caption function to be activated. how to do that?
# Answer:  when the focus is moved to the icon, a list of quick settings icons appears above the top of the menu. you can quickly set frequently used functions by clicking the icons. you can watch tv broadcasts with captions. to activate/deactivate the caption function, press the select button. to run accessibility shortcuts, press the up directional button, and then select accessibility shortcuts.

# %% [markdown]
# ##### Dataframe to output some random user queries and questions retrieved out of the e-manual for the two models, BOW and W2Vec.

# %%
df_show = pd.read_csv("user_queries.csv")
df_show

# after long search I couldn't get a solution to show the complete column intead of '...'
# A solution will be highly appreciable.
# Out:
#    user_queries
# 0   what is picture mode?                         ...
# 1   how to activate the caption function?         ...
# 2   what is the use of universal guide?           ...
# 3   can i remove item on the home screen?         ...
# 4   how can i manage my payment information saved ...
# 5   what are the features of app service?         ...
# 6   how to launch app?                            ...
# 7   how can i check app details?                  ...
# 8   where to view photos?                         ...
# 9   can i play media content saved on my mobile?  ...
# 10  signal information under self diagnosis isn't ...
# 11  the tv is tilted to the side. what should i do...
# 12  why the remote control or voice control is not...
# 13  why my settings are lost after every 5 minutes...
# 14  why my tv is making a popping noise?          ...
# 15  tv is making a humming noise. what should i do...
# 16  how do i select high contrast?                ...
# 17  how do i use the accessibility shortcuts menu?...
# 18  how do i use virtual numeric pad?             ...
# 19  how do i change volume?                       ...
# 20  how do i record a program?                    ...
# 21  how can i record my scheduled program?        ...
# 22  how can i view scheduled program for multiple ...
# 23  how do i activate the caption?                ...

# %%
def retrieveQuestion(question_embedding,sentence_embeddings,sentences):
    max_sim=-1
    index_sim=-1
    for index,eManual_embedding in enumerate(sentence_embeddings):
        sim=cosine_similarity(eManual_embedding,question_embedding)[0][0]
        if sim>max_sim:
            max_sim=sim
            index_sim=index
    
    return df.iloc[index_sim,0]

# %%
# function to display df of retrieved queries from BOW and word2vec model

def show_user(df_show):
    cosine_list = []
    w2vec_list = []
    
    for i in range(df_show.shape[0]):
        question_orig = df_show.iloc[i, 0]
        question = clean_sentence(question_orig,stopwords=False)
        question_embedding = dictionary.doc2bow(question.split())
        
        retreivedQuestion = retrieveQuestion(question_embedding,bow_corpus,sentences)
        cosine_list.append(retreivedQuestion)
        
        question_embedding_w2v = getPhraseEmbedding(question,w2v_model)
        retreivedQuestion_w2v = retrieveQuestion(question_embedding_w2v,sent_embeddings,cleaned_sentences)
        w2vec_list.append(retreivedQuestion_w2v)
    
    df_show['bow'] = cosine_list
    df_show['w2vec'] = w2vec_list
    return df_show

df_temp = show_user(df_show)
df_temp
# Out:
#    user_queries                                                                      \
# 0   what is picture mode?                         ...
# 1   how to activate the caption function?         ...
# 2   what is the use of universal guide?           ...
# 3   can i remove item on the home screen?         ...
# 4   how can i manage my payment information saved ...
# 5   what are the features of app service?         ...
# 6   how to launch app?                            ...
# 7   how can i check app details?                  ...
# 8   where to view photos?                         ...
# 9   can i play media content saved on my mobile?  ...
# 10  signal information under self diagnosis isn't ...
# 11  the tv is tilted to the side. what should i do...
# 12  why the remote control or voice control is not...
# 13  why my settings are lost after every 5 minutes...
# 14  why my tv is making a popping noise?          ...
# 15  tv is making a humming noise. what should i do...
# 16  how do i select high contrast?                ...
# 17  how do i use the accessibility shortcuts menu?...
# 18  how do i use virtual numeric pad?             ...
# 19  how do i change volume?                       ...
# 20  how do i record a program?                    ...
# 21  how can i record my scheduled program?        ...
# 22  how can i view scheduled program for multiple ...
# 23  how do i activate the caption?                ...
#
#                                                   bow  \
# 0                                 what is sound mode?
# 1      how to turn on the autorun smart hub function?
# 2                                 what is sound mode?
# 3           where can i can view the current network?
# 4           where can i can view the current network?
# 5       what are the uses of buttons in the e-manual?
# 6                             how to reset smart hub?
# 7   can i create a samsung account using a paypal ...
# 8                       where to view privacy policy?
# 9   can i create a samsung account using a paypal ...
# 10                i need to lock app. how to do this?
# 11                                what is sound mode?
# 12                                what is sound mode?
# 13                  my tv screen becomes darker. why?
# 14                                what is sound mode?
# 15                                what is sound mode?
# 16                i need to lock app. how to do this?
# 17          where can i can view the current network?
# 18                i need to lock app. how to do this?
# 19                i need to lock app. how to do this?
# 20                i need to lock app. how to do this?
# 21  can i create a samsung account using a paypal ...
# 22  can i create a samsung account using a paypal ...
# 23          where can i can view the current network?
#
#                                                 w2vec
# 0                     how to change the picture mode?
# 1                can i activate the caption function?
# 2                 what is the use of universal guide?
# 3                how to move item on the home screen?
# 4   i want to know the information about the tv. h...
# 5   i want to use the feature of apps. how can i d...
# 6      how to launch the last used app automatically?
# 7                            can i check app details?
# 8                       where can i view bixby guide?
# 9          can i turn on the tv with a mobile device?
# 10  i need the caption function to be activated. h...
# 11  i want to know the information about the tv. h...
# 12                     what does remote support mean?
# 13  why my settings are lost everytime the tv is t...
# 14             what can i do if my tv is getting hot?
# 15  i want to know the information about the tv. h...
# 16  how do i use voice guide and how do i select h...
# 17    how do i open the accessibility shortcuts menu?
# 18  what all things must be required to use the bi...
# 19                       how do i change auto volume?
# 20  please instruct how to record any program and ...
# 21  please instruct how to record any program and ...
# 22  how can i view the channels that are serached ...
# 23               can i activate the caption function?
